# %%
from dataclasses import dataclass

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# ### Set seeds for reproducibility

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Check for GPU availability

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"Using GPU: {gpus}")
else:
    print("Using CPU")
# Out:
# Using GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
lob_features = [
    "b0p", "b1p", "b2p", "b3p", "b4p", "b5p", "b6p", "b7p", "b8p", "b9p",
    "b0q", "b1q", "b2q", "b3q", "b4q", "b5q", "b6q", "b7q", "b8q", "b9q",
    "a0p", "a1p", "a2p", "a3p", "a4p", "a5p", "a6p", "a7p", "a8p", "a9p",
    "a0q", "a1q", "a2q", "a3q", "a4q", "a5q", "a6q", "a7q", "a8q", "a9q"
]

# %%
@dataclass
class Config:
    z_dim = 2*100  # Dimension of random noise
    batch_size = 64
    learning_rate_g = 0.0002
    learning_rate_d = 0.0002
    epochs = 100
    penalty_weight = 5
    sample_size = 5000
    faulty_rate_weight = 20

config = Config()

# %% [markdown]
# ### Load and preprocess LOB data

# %%
file_path = "E:\DSA5204 Project\DSA5204-Group-9\lob\BTCUSDT-lob.parq"
df = pd.read_parquet(file_path, engine="pyarrow")

print(f"The legnth for the dataframe is {len(df)}")
# Out:
# The legnth for the dataframe is 189760

# %%
df.iloc[:, 25:35].head()
# Out:
#        a0p      a1p      a2p      a3p      a4p      a5p      a6p      a7p  \
# 0  95180.0  95180.1  95180.2  95180.6  95180.7  95180.8  95181.5  95181.6
# 1  95180.0  95180.1  95180.6  95180.7  95180.8  95181.5  95181.6  95181.8
# 2  95180.0  95180.1  95180.4  95180.6  95180.7  95180.8  95181.5  95181.6
# 3  95180.0  95180.1  95180.4  95180.6  95180.7  95180.8  95181.5  95181.6
# 4  95180.0  95180.1  95180.4  95180.6  95180.7  95180.8  95181.5  95181.6
#
#        a8p      a9p
# 0  95181.8  95181.9
# 1  95181.9  95182.0
# 2  95181.8  95181.9
# 3  95181.8  95181.9
# 4  95181.8  95181.9

# %%
df = df.dropna(subset=lob_features).sample(n=config.sample_size, random_state=42)

# %%
scaler = MinMaxScaler()
lob_data = scaler.fit_transform(df[lob_features].values).astype(np.float32) #(5000, 40)
lob_dataset = tf.data.Dataset.from_tensor_slices(lob_data).batch(config.batch_size)

#lob_dataset: TensorFlow Dataset object

# %%
for batch in lob_dataset.take(1):
    print(f"Dimension of lob_dataset: {batch.shape}")
# Out:
# Dimension of lob_dataset: (64, 40)

# %% [markdown]
# ### Generator

# %%
class Generator(models.Model):
    def __init__(self, config):
        super(Generator, self).__init__()
        self.config = config
        self.z_dim = config.z_dim
        
        # For price vector (20 feature: 10 bid + 10 ask)
        self.price_dense = layers.Dense(40)
        
        # For quantity vector generation, ensure all are positive.
        self.q_dense1 = layers.Dense(128, activation='relu')
        # self.q_dense2 = layers.Dense(64, activation='relu')
        # self.q_dense3 = layers.Dense(32, activation='relu')
        self.q_output = layers.Dense(20)

    def call(self, inputs, training=True):
        # Split noise into two parts: one for price, one for quantity
        z_price, z_volume = tf.split(inputs, num_or_size_splits=2, axis=1)
        
        # Generate price vector
        x_price = tf.nn.relu(tf.math.exp(z_price))  # non-negative + relu
        price_output = self.price_dense(x_price)
        bid_prices = price_output[:, :10]
        ask_prices = price_output[:, 10:20]
        
        # Quantity vector generation
        x_q = self.q_dense1(z_volume)
        # x_q = self.q_dense2(x_q)
        # x_q = self.q_dense3(x_q)
        quantity_output = self.q_output(x_q)
        bid_quantities = quantity_output[:, :10]
        ask_quantities = quantity_output[:, 10:20]
        
        # Combine: [b0p...b9p, b0q...b9q, a0p...a9p, a0q...a9q]
        combined = tf.concat([bid_prices, bid_quantities, ask_prices, ask_quantities], axis=1)
        return combined

# %% [markdown]
# ### Minibatch Discriminator

# %%
# Minibatch Discrimination code
class MinibatchDiscrimination(layers.Layer):
    """Minibatch discrimination layer to prevent mode collapse"""

    def __init__(self, num_kernels=100, dim_per_kernel=5, **kwargs):
        super(MinibatchDiscrimination, self).__init__(**kwargs)
        self.num_kernels = num_kernels
        self.dim_per_kernel = dim_per_kernel

    def build(self, input_shape):
        #Defines a trainable weight (self.kernel) of shape (input_dim, num_kernels, dim_per_kernel)
        self.input_dim = input_shape[1] #Stores the number of features in the input tensor.
        kernel_shape = (self.input_dim, self.num_kernels, self.dim_per_kernel) #Shape of the kernel tensor
        initializer = tf.random_normal_initializer(stddev=0.02)
        self.kernel = self.add_weight(
            shape=kernel_shape,
            initializer=initializer,
            name='kernel',
            trainable=True
        )
        super(MinibatchDiscrimination, self).build(input_shape)

    def call(self, inputs, **kwargs):
        #Computes a projection of inputs using self.kernel.
        #If inputs has shape (batch_size, input_dim),
        #And kernel has shape (input_dim, num_kernels, dim_per_kernel),
        #Then activation will have shape (batch_size, num_kernels, dim_per_kernel).
        #Got from dot product.
        activation = tf.tensordot(inputs, self.kernel, axes=[[1], [0]])
        
        #Expands dimensions to compare all batch samples.
        expanded_act = tf.expand_dims(activation, 3)
        transposed_act = tf.expand_dims(tf.transpose(activation, [1, 2, 0]), 0)

        diff = expanded_act - transposed_act #
        abs_diff = tf.reduce_sum(tf.abs(diff), 2) #Computes the absolute differences between all pairs of samples.

        #Apply mask to avoid comparing a sample with itself.
        batch_size = tf.shape(inputs)[0]
        mask = 1.0 - tf.eye(batch_size) 
        #Creates an identity matrix (tf.eye(batch_size)), which has 1s on the diagonal and subtracts it from 1.0. Ensures that the diagonal is 0.
        mask = tf.expand_dims(mask, 1)

        #Expands dimensions to match abs_diff.
        if mask.shape.ndims != abs_diff.shape.ndims:
            mask = tf.reshape(mask, [-1, mask.shape[1], batch_size])

        exp = tf.exp(-abs_diff) * mask
        minibatch_features = tf.reduce_sum(exp, 2)

        return tf.concat([inputs, minibatch_features], axis=1)

# %% [markdown]
# The final shape is (batch_size, input_dim + num_kernels).

# %% [markdown]
# ### Discriminator

# %% [markdown]
# No batch normalization for discriminator as BatchNorm normalizes across the batch, which may leak information between examples.

# %%
class Discriminator(models.Model):
    """Simple Discriminator for classifying real vs fake feature vectors with financial constraints"""
    def __init__(self, config, use_minibatch_discrimination=False):
        super(Discriminator, self).__init__()
        self.config = config
        self.use_minibatch_discrimination = use_minibatch_discrimination  # Store the flag
        
        # Price Stream:
        self.price_dense = layers.Dense(20) #No activation
        
        # Quantity Stream:
        self.quantity_dense = layers.Dense(20, activation = 'relu')
        
        # Shared layers after combining both streams
        self.dense1 = layers.Dense(512)
        self.leaky1 = layers.LeakyReLU(alpha=0.2)
        
        self.dense2 = layers.Dense(256)
        self.leaky2 = layers.LeakyReLU(alpha=0.2) 
          
        if use_minibatch_discrimination:
            self.minibatch_layer = MinibatchDiscrimination(num_kernels=100, dim_per_kernel=5)

        self.dense3 = layers.Dense(128)
        self.leaky3 = layers.LeakyReLU(alpha=0.2)

        self.dense4 = layers.Dense(64)
        self.leaky4 = layers.LeakyReLU(alpha=0.2)
        
        self.output_layer = layers.Dense(1) #Just a real/ fake classification
    
    def call(self, input, training=True):
        # Split input: [b0p..b9p, b0q..b9q, a0p..a9p, a0q..a9q]
        bid_price = input[:, :10]
        bid_quantity = input[:, 10:20]
        ask_price = input[:, 20:30]
        ask_quantity = input[:, 30:40]
        
        # Combine price and quantity vectors:
        price_vector = tf.concat([bid_price, ask_price], axis=1)
        quantity_vector = tf.concat([bid_quantity, ask_quantity], axis=1)
        
        # Apply respective processing
        price_out = self.price_dense(price_vector)
        quantity_out = self.quantity_dense(quantity_vector)
        
        # Combine processed features
        x = tf.concat([price_out, quantity_out], axis=1)
        
        x = self.dense1(x)
        x = self.leaky1(x)
        
        x = self.dense2(x)
        x = self.leaky2(x)
        
        if self.use_minibatch_discrimination:
            x = self.minibatch_layer(x)

        x = self.dense3(x)
        x = self.leaky3(x)

        x = self.dense4(x)
        x = self.leaky4(x)

        output = self.output_layer(x)

        return output

# %%
class SimpleGAN:
    """Simplest GAN using a Generator and a Discriminator.
       Includes differentiable soft penalty for LOB rules.
    """
    def __init__(self, config, use_minibatch_discrimination=False):
        self.config = config
        self.generator = Generator(config)
        self.discriminator = Discriminator(config, use_minibatch_discrimination=use_minibatch_discrimination)
        self.gen_optimizer = tf.keras.optimizers.Adam(config.learning_rate_g)
        self.disc_optimizer = tf.keras.optimizers.Adam(config.learning_rate_d)
        self.fixed_noise = tf.random.normal([16, config.z_dim])

    def generator_loss(self, fake_output, generated_lob):
        target = tf.ones_like(fake_output)
        adv_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(target, fake_output, from_logits=True))
        penalty = differentiable_faulty_penalty(generated_lob)
        penalty_loss = tf.reduce_mean(penalty)
        total_loss = adv_loss + self.config.faulty_rate_weight * penalty_loss
        return total_loss, adv_loss, penalty_loss

    def discriminator_loss(self, real_output, fake_output):
        real_labels = tf.ones_like(real_output)
        fake_labels = tf.zeros_like(fake_output)
        real_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(real_labels, real_output, from_logits=True))
        fake_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(fake_labels, fake_output, from_logits=True))
        return real_loss + fake_loss

    @tf.function
    def train_step(self, real_matrices):
        batch_size = tf.shape(real_matrices)[0]
        noise = tf.random.normal([batch_size, self.config.z_dim])

        with tf.GradientTape() as disc_tape:
            fake_matrices = self.generator(noise, training=True)
            real_output = self.discriminator(real_matrices, training=True)
            fake_output = self.discriminator(fake_matrices, training=True)
            disc_loss = self.discriminator_loss(real_output, fake_output)

        disc_gradients = disc_tape.gradient(disc_loss, self.discriminator.trainable_variables)
        self.disc_optimizer.apply_gradients(zip(disc_gradients, self.discriminator.trainable_variables))

        with tf.GradientTape() as gen_tape:
            fake_matrices = self.generator(noise, training=True)
            fake_output = self.discriminator(fake_matrices, training=True)
            gen_loss, adv_loss, penalty_loss = self.generator_loss(fake_output, fake_matrices)

        gen_gradients = gen_tape.gradient(gen_loss, self.generator.trainable_variables)
        self.gen_optimizer.apply_gradients(zip(gen_gradients, self.generator.trainable_variables))

        return {
            "gen_loss": gen_loss,
            "disc_loss": disc_loss,
            "adv_loss": adv_loss,
            "penalty_loss": penalty_loss
        }

# %% [markdown]
# ### Reasonability Check functions:

# %%
def differentiable_faulty_penalty(lob_tensor):
    """Differentiable soft constraint penalty for LOB rules (usable in generator loss)."""

    bid_prices = lob_tensor[:, :10]        # b0p - b9p
    bid_quantities = lob_tensor[:, 10:20]  # b0q - b9q
    ask_prices = lob_tensor[:, 20:30]      # a0p - a9p
    ask_quantities = lob_tensor[:, 30:40]  # a0q - a9q

    # 1. Soft penalty for best_bid >= best_ask (should be best_bid < best_ask)
    best_bid = bid_prices[:, -1]  # b9p
    best_ask = ask_prices[:, 0]  # a0p
    spread_violation = tf.nn.softplus(best_bid - best_ask)  # positive when constraint is violated

    # 2. Bid prices should decrease: b0 > b1 > ... > b9
    bid_diff = bid_prices[:, :-1] - bid_prices[:, 1:]
    bid_order_penalty = tf.reduce_sum(tf.nn.relu(-bid_diff), axis=1)

    # 3. Ask prices should increase: a0 < a1 < ... < a9
    ask_diff = ask_prices[:, 1:] - ask_prices[:, :-1]
    ask_order_penalty = tf.reduce_sum(tf.nn.relu(-ask_diff), axis=1)

    # 4. Volumes must be >= 0
    bid_volume_penalty = tf.reduce_sum(tf.nn.relu(-bid_quantities), axis=1)
    ask_volume_penalty = tf.reduce_sum(tf.nn.relu(-ask_quantities), axis=1)

    # Combine all penalties per sample
    total_penalty = spread_violation + bid_order_penalty + ask_order_penalty + bid_volume_penalty + ask_volume_penalty

    return total_penalty  # Shape: (batch_size,)

# %% [markdown]
# differentiable_faulty_penalty: Act as a differentiable penalty function.
#
# Why this works?
#
#
# - Replaces non-differentiable hard constraints with smooth or subdifferentiable approximations that are compatible with backpropagation and gradient-based optimization.
#
#
#  Spread Violation
# - $softplus(x) = log(1 + exp(x))$ is a smooth, differentiable approximation of ```relu(x)```.
#
#
#  Bid/ Ask Price Ordering
#  - ```tf.nn.relu``` is subdifferentiable. That’s sufficient for most optimizers (like Adam) in practice.
#
#
#  Volume Positivity
#  - ```relu``` is again subdifferentiable and well-handled in Tensorflow.

# %%
def compute_faulty_rate(lob_tensor):
    """Calculates the faulty rate for synthetic LOB data using TensorFlow tensors."""
    
    bid_prices = lob_tensor[:, :10]  # First 10 columns are bid prices
    ask_prices = lob_tensor[:, 20:30]  # Columns 20-30 are ask prices
    bid_quantities = lob_tensor[:, 10:20]  # Columns 10-20 are bid quantities
    ask_quantities = lob_tensor[:, 30:40]  # Columns 30-40 are ask quantities

    faulty_count = tf.zeros(1, dtype=tf.float32)  # Initialize faulty count

    # 1. Ensure best bid price < best ask price (b0p < a0p)
    max_bid = tf.reduce_max(bid_prices, axis=1)  # Get the highest bid
    min_ask = tf.reduce_min(ask_prices, axis=1)  # Get the lowest ask
    faulty_count += tf.reduce_sum(tf.cast(max_bid >= min_ask, tf.float32))  # Count violations

    # 2. Bid prices should be in descending order (b0p > b1p > ...)
    faulty_count += tf.reduce_sum(tf.cast(tf.experimental.numpy.diff(bid_prices, axis=1) >= 0, tf.float32))

    # 3. Ask prices should be in ascending order (a0p < a1p < ...)
    faulty_count += tf.reduce_sum(tf.cast(tf.experimental.numpy.diff(ask_prices, axis=1) <= 0, tf.float32))

    # 4. Bid and ask quantities should be non-negative
    faulty_count += tf.reduce_sum(tf.cast(bid_quantities < 0, tf.float32))
    faulty_count += tf.reduce_sum(tf.cast(ask_quantities < 0, tf.float32))
    faulty_count += tf.reduce_sum(tf.cast(bid_prices < 0, tf.float32))
    faulty_count += tf.reduce_sum(tf.cast(ask_prices < 0, tf.float32))

    # Compute faulty rate as a percentage of all elements
    total_elements = tf.size(lob_tensor, out_type=tf.float32)
    faulty_rate = faulty_count / total_elements  # Returns a TensorFlow tensor

    return faulty_rate.numpy()  # Convert to NumPy for further processing

# %% [markdown]
# Records down the faulty rate at the end of each epoch and plot the change.

# %%
def plot_training_trends(gen_losses, disc_losses, faulty_rates, label_prefix="GAN"):
    epochs_arr = np.arange(1, len(gen_losses) + 1)

    fig, axs = plt.subplots(3, 1, figsize=(12, 12), sharex=True)

    # Plot 1: Generator Loss
    axs[0].plot(epochs_arr, gen_losses, color='tab:blue', marker='o')
    axs[0].set_ylabel("Generator Loss")
    axs[0].set_title(f"{label_prefix} - Generator Loss")
    axs[0].grid(True)

    # Plot 2: Discriminator Loss
    axs[1].plot(epochs_arr, disc_losses, color='tab:green', marker='s')
    axs[1].set_ylabel("Discriminator Loss")
    axs[1].set_title(f"{label_prefix} - Discriminator Loss")
    axs[1].grid(True)

    # Plot 3: Faulty Rate
    axs[2].plot(epochs_arr, faulty_rates, color='tab:red', marker='^')
    axs[2].set_ylabel("Faulty Rate")
    axs[2].set_xlabel("Epoch")
    axs[2].set_title(f"{label_prefix} - Faulty Rate")
    axs[2].grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Train normal

# %%
gan = SimpleGAN(config, use_minibatch_discrimination=False)

# History tracking
gen_loss_history = []
disc_loss_history = []
adv_loss_history = []
penalty_loss_history = []
faulty_rate_history = []

for epoch in range(config.epochs):
    epoch_gen_loss = 0.0
    epoch_disc_loss = 0.0
    epoch_adv_loss = 0.0
    epoch_penalty_loss = 0.0
    num_batches = 0

    for batch in lob_dataset:
        metrics = gan.train_step(batch)
        epoch_gen_loss += metrics['gen_loss']
        epoch_disc_loss += metrics['disc_loss']
        epoch_adv_loss += metrics['adv_loss']
        epoch_penalty_loss += metrics['penalty_loss']
        num_batches += 1

    avg_gen_loss = epoch_gen_loss / num_batches
    avg_disc_loss = epoch_disc_loss / num_batches
    avg_adv_loss = epoch_adv_loss / num_batches
    avg_penalty_loss = epoch_penalty_loss / num_batches

    gen_loss_history.append(float(avg_gen_loss))
    disc_loss_history.append(float(avg_disc_loss))
    adv_loss_history.append(float(avg_adv_loss))
    penalty_loss_history.append(float(avg_penalty_loss))

    # Compute Faulty Rate on sampled LOBs
    noise = tf.random.normal([100, config.z_dim])
    generated_samples = gan.generator(noise, training=False)
    faulty_rate = compute_faulty_rate(generated_samples)
    faulty_rate_scalar = float(faulty_rate.item())  # Convert ndarray → Python float
    faulty_rate_history.append(faulty_rate_scalar)

    print(f"Epoch {epoch+1}/{config.epochs} - "
          f"Gen Loss: {avg_gen_loss:.4f} (Adv: {avg_adv_loss:.4f}, Penalty: {avg_penalty_loss:.4f}), "
          f"Disc Loss: {avg_disc_loss:.4f}, "
          f"Faulty Rate: {faulty_rate_scalar:.4f}")

plot_training_trends(gen_loss_history, disc_loss_history, faulty_rate_history, label_prefix="GAN")
# Out:
# Epoch 1/100 - Gen Loss: 615.6571 (Adv: 7.0422, Penalty: 30.4307), Disc Loss: 0.2395, Faulty Rate: 0.6175
# Epoch 2/100 - Gen Loss: 460.8640 (Adv: 11.4728, Penalty: 22.4696), Disc Loss: 0.0354, Faulty Rate: 0.5315
# Epoch 3/100 - Gen Loss: 359.2520 (Adv: 13.3728, Penalty: 17.2940), Disc Loss: 0.0114, Faulty Rate: 0.5023
# Epoch 4/100 - Gen Loss: 284.5042 (Adv: 15.6245, Penalty: 13.4440), Disc Loss: 0.0042, Faulty Rate: 0.4538
# Epoch 5/100 - Gen Loss: 224.3025 (Adv: 19.5285, Penalty: 10.2387), Disc Loss: 0.0025, Faulty Rate: 0.4313
# Epoch 6/100 - Gen Loss: 184.5281 (Adv: 23.8869, Penalty: 8.0321), Disc Loss: 0.0013, Faulty Rate: 0.4010
# Epoch 7/100 - Gen Loss: 148.9214 (Adv: 25.2234, Penalty: 6.1849), Disc Loss: 0.0007, Faulty Rate: 0.3795
# Epoch 8/100 - Gen Loss: 115.5594 (Adv: 26.2145, Penalty: 4.4672), Disc Loss: 0.0004, Faulty Rate: 0.3577
# Epoch 9/100 - Gen Loss: 96.3633 (Adv: 26.9182, Penalty: 3.4723), Disc Loss: 0.0003, Faulty Rate: 0.3462
# Epoch 10/100 - Gen Loss: 80.0378 (Adv: 27.3389, Penalty: 2.6349), Disc Loss: 0.0002, Faulty Rate: 0.3252
# Epoch 11/100 - Gen Loss: 68.1717 (Adv: 27.6206, Penalty: 2.0276), Disc Loss: 0.0001, Faulty Rate: 0.3207
# Epoch 12/100 - Gen Loss: 58.4213 (Adv: 27.6159, Penalty: 1.5403), Disc Loss: 0.0001, Faulty Rate: 0.3158
# Epoch 13/100 - Gen Loss: 54.4265 (Adv: 27.2530, Penalty: 1.3587), Disc Loss: 0.0001, Faulty Rate: 0.3092
# Epoch 14/100 - Gen Loss: 47.2209 (Adv: 27.5778, Penalty: 0.9822), Disc Loss: 0.0001, Faulty Rate: 0.3027
# Epoch 15/100 - Gen Loss: 43.4171 (Adv: 27.2493, Penalty: 0.8084), Disc Loss: 0.0001, Faulty Rate: 0.2988
# Epoch 16/100 - Gen Loss: 40.7375 (Adv: 26.5744, Penalty: 0.7082), Disc Loss: 0.0001, Faulty Rate: 0.2952
# Epoch 17/100 - Gen Loss: 37.3614 (Adv: 25.6938, Penalty: 0.5834), Disc Loss: 0.0000, Faulty Rate: 0.2973
# Epoch 18/100 - Gen Loss: 34.6597 (Adv: 24.7746, Penalty: 0.4943), Disc Loss: 0.0000, Faulty Rate: 0.2928
# Epoch 19/100 - Gen Loss: 32.1214 (Adv: 23.8652, Penalty: 0.4128), Disc Loss: 0.0000, Faulty Rate: 0.3015
# Epoch 20/100 - Gen Loss: 31.6485 (Adv: 24.2359, Penalty: 0.3706), Disc Loss: 0.0001, Faulty Rate: 0.2898
# Epoch 21/100 - Gen Loss: 34.0723 (Adv: 27.7123, Penalty: 0.3180), Disc Loss: 0.0000, Faulty Rate: 0.2918
# Epoch 22/100 - Gen Loss: 32.7369 (Adv: 26.5813, Penalty: 0.3078), Disc Loss: 0.0000, Faulty Rate: 0.2948
# Epoch 23/100 - Gen Loss: 31.2022 (Adv: 25.6407, Penalty: 0.2781), Disc Loss: 0.0000, Faulty Rate: 0.2907
# Epoch 24/100 - Gen Loss: 29.4616 (Adv: 24.5070, Penalty: 0.2477), Disc Loss: 0.0000, Faulty Rate: 0.3050
# Epoch 25/100 - Gen Loss: 27.9362 (Adv: 23.4878, Penalty: 0.2224), Disc Loss: 0.0000, Faulty Rate: 0.3002
# Epoch 26/100 - Gen Loss: 26.3461 (Adv: 22.4232, Penalty: 0.1961), Disc Loss: 0.0000, Faulty Rate: 0.3007
# Epoch 27/100 - Gen Loss: 29.5984 (Adv: 25.7737, Penalty: 0.1912), Disc Loss: 0.0001, Faulty Rate: 0.2973
# Epoch 28/100 - Gen Loss: 34.5841 (Adv: 30.8500, Penalty: 0.1867), Disc Loss: 0.0000, Faulty Rate: 0.3038
# Epoch 29/100 - Gen Loss: 32.6354 (Adv: 29.3518, Penalty: 0.1642), Disc Loss: 0.0000, Faulty Rate: 0.3030
# Epoch 30/100 - Gen Loss: 31.2728 (Adv: 27.8668, Penalty: 0.1703), Disc Loss: 0.0000, Faulty Rate: 0.3113
# Epoch 31/100 - Gen Loss: 30.0278 (Adv: 26.6888, Penalty: 0.1669), Disc Loss: 0.0000, Faulty Rate: 0.3052
# Epoch 32/100 - Gen Loss: 28.5469 (Adv: 25.4209, Penalty: 0.1563), Disc Loss: 0.0000, Faulty Rate: 0.3220
# Epoch 33/100 - Gen Loss: 26.9998 (Adv: 24.2764, Penalty: 0.1362), Disc Loss: 0.0000, Faulty Rate: 0.3190
# Epoch 34/100 - Gen Loss: 26.0131 (Adv: 23.2344, Penalty: 0.1389), Disc Loss: 0.0000, Faulty Rate: 0.3133
# Epoch 35/100 - Gen Loss: 25.0709 (Adv: 22.2236, Penalty: 0.1424), Disc Loss: 0.0000, Faulty Rate: 0.3260
# Epoch 36/100 - Gen Loss: 23.9285 (Adv: 21.3880, Penalty: 0.1270), Disc Loss: 0.0000, Faulty Rate: 0.3288
# Epoch 37/100 - Gen Loss: 22.8749 (Adv: 20.4570, Penalty: 0.1209), Disc Loss: 0.0000, Faulty Rate: 0.3220
# Epoch 38/100 - Gen Loss: 21.8810 (Adv: 19.5449, Penalty: 0.1168), Disc Loss: 0.0000, Faulty Rate: 0.3405
# Epoch 39/100 - Gen Loss: 21.2524 (Adv: 18.7461, Penalty: 0.1253), Disc Loss: 0.0000, Faulty Rate: 0.3315
# Epoch 40/100 - Gen Loss: 20.2414 (Adv: 18.0935, Penalty: 0.1074), Disc Loss: 0.0000, Faulty Rate: 0.3375
# Epoch 41/100 - Gen Loss: 19.8440 (Adv: 17.8707, Penalty: 0.0987), Disc Loss: 0.0000, Faulty Rate: 0.3420
# Epoch 42/100 - Gen Loss: 26.0995 (Adv: 24.2752, Penalty: 0.0912), Disc Loss: 0.0000, Faulty Rate: 0.3330
# Epoch 43/100 - Gen Loss: 25.1770 (Adv: 23.2121, Penalty: 0.0982), Disc Loss: 0.0000, Faulty Rate: 0.3442
# Epoch 44/100 - Gen Loss: 24.0852 (Adv: 22.1348, Penalty: 0.0975), Disc Loss: 0.0000, Faulty Rate: 0.3425
# Epoch 45/100 - Gen Loss: 23.0070 (Adv: 20.9786, Penalty: 0.1014), Disc Loss: 0.0000, Faulty Rate: 0.3395
# Epoch 46/100 - Gen Loss: 21.7928 (Adv: 19.9279, Penalty: 0.0932), Disc Loss: 0.0000, Faulty Rate: 0.3562
# Epoch 47/100 - Gen Loss: 21.3716 (Adv: 19.4799, Penalty: 0.0946), Disc Loss: 0.0041, Faulty Rate: 0.3575
# Epoch 48/100 - Gen Loss: 27.8356 (Adv: 25.6941, Penalty: 0.1071), Disc Loss: 0.0000, Faulty Rate: 0.3925
# Epoch 49/100 - Gen Loss: 25.5580 (Adv: 22.7395, Penalty: 0.1409), Disc Loss: 0.0000, Faulty Rate: 0.3870
# Epoch 50/100 - Gen Loss: 23.5842 (Adv: 20.7632, Penalty: 0.1410), Disc Loss: 0.0000, Faulty Rate: 0.4095
# Epoch 51/100 - Gen Loss: 23.3533 (Adv: 20.3629, Penalty: 0.1495), Disc Loss: 0.0000, Faulty Rate: 0.3975
# Epoch 52/100 - Gen Loss: 22.4529 (Adv: 19.2428, Penalty: 0.1605), Disc Loss: 0.0000, Faulty Rate: 0.4155
# Epoch 53/100 - Gen Loss: 21.8354 (Adv: 18.7278, Penalty: 0.1554), Disc Loss: 0.0015, Faulty Rate: 0.3792
# Epoch 54/100 - Gen Loss: 28.7637 (Adv: 25.6023, Penalty: 0.1581), Disc Loss: 0.0005, Faulty Rate: 0.4038
# Epoch 55/100 - Gen Loss: 25.3737 (Adv: 21.8404, Penalty: 0.1767), Disc Loss: 0.0000, Faulty Rate: 0.4010
# Epoch 56/100 - Gen Loss: 23.3838 (Adv: 19.8271, Penalty: 0.1778), Disc Loss: 0.0001, Faulty Rate: 0.4070
# Epoch 57/100 - Gen Loss: 23.1894 (Adv: 19.4022, Penalty: 0.1894), Disc Loss: 0.0001, Faulty Rate: 0.4092
# Epoch 58/100 - Gen Loss: 22.3261 (Adv: 18.3322, Penalty: 0.1997), Disc Loss: 0.0042, Faulty Rate: 0.4425
# Epoch 59/100 - Gen Loss: 19.2431 (Adv: 16.1494, Penalty: 0.1547), Disc Loss: 0.0001, Faulty Rate: 0.3708
# Epoch 60/100 - Gen Loss: 18.1420 (Adv: 15.5275, Penalty: 0.1307), Disc Loss: 0.0016, Faulty Rate: 0.3485
# Epoch 61/100 - Gen Loss: 21.7978 (Adv: 18.0184, Penalty: 0.1890), Disc Loss: 0.0001, Faulty Rate: 0.3475
# Epoch 62/100 - Gen Loss: 22.9906 (Adv: 18.9943, Penalty: 0.1998), Disc Loss: 0.0022, Faulty Rate: 0.3623
# Epoch 63/100 - Gen Loss: 22.4694 (Adv: 18.5006, Penalty: 0.1984), Disc Loss: 0.0007, Faulty Rate: 0.3880
# Epoch 64/100 - Gen Loss: 21.6551 (Adv: 17.3328, Penalty: 0.2161), Disc Loss: 0.0001, Faulty Rate: 0.4058
# Epoch 65/100 - Gen Loss: 20.7548 (Adv: 16.6838, Penalty: 0.2036), Disc Loss: 0.0001, Faulty Rate: 0.3593
# Epoch 66/100 - Gen Loss: 21.0513 (Adv: 16.5686, Penalty: 0.2241), Disc Loss: 0.0002, Faulty Rate: 0.3938
# Epoch 67/100 - Gen Loss: 21.3512 (Adv: 16.5655, Penalty: 0.2393), Disc Loss: 0.0001, Faulty Rate: 0.3753
# Epoch 68/100 - Gen Loss: 21.1830 (Adv: 16.2977, Penalty: 0.2443), Disc Loss: 0.0002, Faulty Rate: 0.3483
# Epoch 69/100 - Gen Loss: 22.0207 (Adv: 16.8101, Penalty: 0.2605), Disc Loss: 0.0003, Faulty Rate: 0.4062
# Epoch 70/100 - Gen Loss: 22.1489 (Adv: 16.6389, Penalty: 0.2755), Disc Loss: 0.0002, Faulty Rate: 0.4185
# Epoch 71/100 - Gen Loss: 22.6006 (Adv: 16.7291, Penalty: 0.2936), Disc Loss: 0.0003, Faulty Rate: 0.3680
# Epoch 72/100 - Gen Loss: 23.2761 (Adv: 16.7250, Penalty: 0.3276), Disc Loss: 0.0044, Faulty Rate: 0.4505
# Epoch 73/100 - Gen Loss: 26.0617 (Adv: 17.1603, Penalty: 0.4451), Disc Loss: 0.0037, Faulty Rate: 0.3950
# Epoch 74/100 - Gen Loss: 26.4850 (Adv: 16.9417, Penalty: 0.4772), Disc Loss: 0.0019, Faulty Rate: 0.3800
# Epoch 75/100 - Gen Loss: 29.2962 (Adv: 18.2194, Penalty: 0.5538), Disc Loss: 0.0053, Faulty Rate: 0.4532
# Epoch 76/100 - Gen Loss: 33.1560 (Adv: 19.8198, Penalty: 0.6668), Disc Loss: 0.0265, Faulty Rate: 0.4380
# Epoch 77/100 - Gen Loss: 34.1732 (Adv: 20.7694, Penalty: 0.6702), Disc Loss: 0.0248, Faulty Rate: 0.4387
# Epoch 78/100 - Gen Loss: 37.4734 (Adv: 22.8024, Penalty: 0.7335), Disc Loss: 0.0433, Faulty Rate: 0.4428
# Epoch 79/100 - Gen Loss: 38.5536 (Adv: 23.2815, Penalty: 0.7636), Disc Loss: 0.0333, Faulty Rate: 0.3988
# Epoch 80/100 - Gen Loss: 38.7148 (Adv: 23.7316, Penalty: 0.7492), Disc Loss: 0.0233, Faulty Rate: 0.3900
# Epoch 81/100 - Gen Loss: 39.0415 (Adv: 23.6633, Penalty: 0.7689), Disc Loss: 0.0441, Faulty Rate: 0.3957
# Epoch 82/100 - Gen Loss: 40.4172 (Adv: 24.5665, Penalty: 0.7925), Disc Loss: 0.0688, Faulty Rate: 0.4367
# Epoch 83/100 - Gen Loss: 41.3023 (Adv: 24.5995, Penalty: 0.8351), Disc Loss: 0.0743, Faulty Rate: 0.4405
# Epoch 84/100 - Gen Loss: 40.2975 (Adv: 22.9888, Penalty: 0.8654), Disc Loss: 0.1183, Faulty Rate: 0.4988
# Epoch 85/100 - Gen Loss: 34.3952 (Adv: 16.7123, Penalty: 0.8841), Disc Loss: 0.2565, Faulty Rate: 0.4633
# Epoch 86/100 - Gen Loss: 27.0637 (Adv: 9.0687, Penalty: 0.8997), Disc Loss: 0.3881, Faulty Rate: 0.4055
# Epoch 87/100 - Gen Loss: 26.3331 (Adv: 6.7356, Penalty: 0.9799), Disc Loss: 0.4938, Faulty Rate: 0.3747
# Epoch 88/100 - Gen Loss: 21.6574 (Adv: 4.1939, Penalty: 0.8732), Disc Loss: 0.5053, Faulty Rate: 0.3817
# Epoch 89/100 - Gen Loss: 18.2032 (Adv: 2.7722, Penalty: 0.7716), Disc Loss: 0.7654, Faulty Rate: 0.4408
# Epoch 90/100 - Gen Loss: 18.0784 (Adv: 2.8450, Penalty: 0.7617), Disc Loss: 0.7526, Faulty Rate: 0.4840
# Epoch 91/100 - Gen Loss: 17.9260 (Adv: 2.7272, Penalty: 0.7599), Disc Loss: 0.8002, Faulty Rate: 0.3180
# Epoch 92/100 - Gen Loss: 18.0690 (Adv: 2.9144, Penalty: 0.7577), Disc Loss: 0.7944, Faulty Rate: 0.2943
# Epoch 93/100 - Gen Loss: 18.8403 (Adv: 3.3900, Penalty: 0.7725), Disc Loss: 0.7900, Faulty Rate: 0.4148
# Epoch 94/100 - Gen Loss: 17.4145 (Adv: 2.5245, Penalty: 0.7445), Disc Loss: 0.8202, Faulty Rate: 0.3990
# Epoch 95/100 - Gen Loss: 18.3013 (Adv: 3.1779, Penalty: 0.7562), Disc Loss: 0.9121, Faulty Rate: 0.3778
# Epoch 96/100 - Gen Loss: 17.7272 (Adv: 2.9165, Penalty: 0.7405), Disc Loss: 0.8479, Faulty Rate: 0.3582
# Epoch 97/100 - Gen Loss: 17.9875 (Adv: 3.3579, Penalty: 0.7315), Disc Loss: 0.7124, Faulty Rate: 0.3840
# Epoch 98/100 - Gen Loss: 19.1490 (Adv: 3.8545, Penalty: 0.7647), Disc Loss: 0.7003, Faulty Rate: 0.3762
# Epoch 99/100 - Gen Loss: 16.8785 (Adv: 2.2906, Penalty: 0.7294), Disc Loss: 0.9038, Faulty Rate: 0.3115
# Epoch 100/100 - Gen Loss: 16.9714 (Adv: 2.3948, Penalty: 0.7288), Disc Loss: 0.8824, Faulty Rate: 0.3408

# %% [markdown]
# ### Testing Minibatch Discriminator

# %%
gan_mindis = SimpleGAN(config, use_minibatch_discrimination=True)

# History tracking
gen_loss_mindis = []
disc_loss_mindis = []
adv_loss_mindis = []
penalty_loss_mindis = []
faulty_rate_mindis = []

for epoch in range(config.epochs):
    epoch_gen_loss = 0.0
    epoch_disc_loss = 0.0
    epoch_adv_loss = 0.0
    epoch_penalty_loss = 0.0
    num_batches = 0

    for batch in lob_dataset:
        metrics = gan_mindis.train_step(batch)
        epoch_gen_loss += metrics['gen_loss']
        epoch_disc_loss += metrics['disc_loss']
        epoch_adv_loss += metrics['adv_loss']
        epoch_penalty_loss += metrics['penalty_loss']
        num_batches += 1

    avg_gen_loss = epoch_gen_loss / num_batches
    avg_disc_loss = epoch_disc_loss / num_batches
    avg_adv_loss = epoch_adv_loss / num_batches
    avg_penalty_loss = epoch_penalty_loss / num_batches

    gen_loss_mindis.append(float(avg_gen_loss))
    disc_loss_mindis.append(float(avg_disc_loss))
    adv_loss_mindis.append(float(avg_adv_loss))
    penalty_loss_mindis.append(float(avg_penalty_loss))

    noise = tf.random.normal([100, config.z_dim])
    generated_samples = gan_mindis.generator(noise, training=False)
    faulty_rate = compute_faulty_rate(generated_samples)
    faulty_rate_scalar = float(faulty_rate.item())  # Convert ndarray → Python float
    faulty_rate_mindis.append(faulty_rate_scalar)



    print(f"Epoch {epoch+1}/{config.epochs} - "
        f"Gen Loss: {avg_gen_loss:.4f} (Adv: {avg_adv_loss:.4f}, Penalty: {avg_penalty_loss:.4f}), "
        f"Disc Loss: {avg_disc_loss:.4f}, "
        f"Faulty Rate: {faulty_rate_scalar:.4f}")



plot_training_trends(gen_loss_mindis, disc_loss_mindis, faulty_rate_mindis, label_prefix="GAN (Minibatch Discrimination)")
# Out:
# Epoch 1/100 - Gen Loss: 691.3664 (Adv: 20.4728, Penalty: 33.5447), Disc Loss: 0.2374, Faulty Rate: 0.5242
# Epoch 2/100 - Gen Loss: 466.7751 (Adv: 18.4264, Penalty: 22.4174), Disc Loss: 0.0060, Faulty Rate: 0.4548
# Epoch 3/100 - Gen Loss: 368.9422 (Adv: 15.7909, Penalty: 17.6576), Disc Loss: 0.0047, Faulty Rate: 0.4225
# Epoch 4/100 - Gen Loss: 301.9255 (Adv: 14.5423, Penalty: 14.3692), Disc Loss: 0.0030, Faulty Rate: 0.3848
# Epoch 5/100 - Gen Loss: 237.5911 (Adv: 14.2098, Penalty: 11.1691), Disc Loss: 0.0025, Faulty Rate: 0.3483
# Epoch 6/100 - Gen Loss: 193.5345 (Adv: 14.4914, Penalty: 8.9522), Disc Loss: 0.0016, Faulty Rate: 0.3318
# Epoch 7/100 - Gen Loss: 153.6280 (Adv: 14.1156, Penalty: 6.9756), Disc Loss: 0.0013, Faulty Rate: 0.3100
# Epoch 8/100 - Gen Loss: 118.6078 (Adv: 14.4487, Penalty: 5.2080), Disc Loss: 0.0010, Faulty Rate: 0.3067
# Epoch 9/100 - Gen Loss: 95.8015 (Adv: 15.1511, Penalty: 4.0325), Disc Loss: 0.0008, Faulty Rate: 0.2970
# Epoch 10/100 - Gen Loss: 79.1612 (Adv: 15.7353, Penalty: 3.1713), Disc Loss: 0.0007, Faulty Rate: 0.2750
# Epoch 11/100 - Gen Loss: 63.2417 (Adv: 16.3393, Penalty: 2.3451), Disc Loss: 0.0006, Faulty Rate: 0.2860
# Epoch 12/100 - Gen Loss: 52.7195 (Adv: 16.4023, Penalty: 1.8159), Disc Loss: 0.0005, Faulty Rate: 0.2623
# Epoch 13/100 - Gen Loss: 46.7828 (Adv: 16.8147, Penalty: 1.4984), Disc Loss: 0.0004, Faulty Rate: 0.2603
# Epoch 14/100 - Gen Loss: 39.5986 (Adv: 17.0713, Penalty: 1.1264), Disc Loss: 0.0004, Faulty Rate: 0.2505
# Epoch 15/100 - Gen Loss: 35.7209 (Adv: 17.5195, Penalty: 0.9101), Disc Loss: 0.0003, Faulty Rate: 0.2485
# Epoch 16/100 - Gen Loss: 34.0930 (Adv: 19.0720, Penalty: 0.7511), Disc Loss: 0.0003, Faulty Rate: 0.2428
# Epoch 17/100 - Gen Loss: 31.3975 (Adv: 19.1671, Penalty: 0.6115), Disc Loss: 0.0003, Faulty Rate: 0.2320
# Epoch 18/100 - Gen Loss: 28.3209 (Adv: 18.6313, Penalty: 0.4845), Disc Loss: 0.0002, Faulty Rate: 0.2377
# Epoch 19/100 - Gen Loss: 26.5416 (Adv: 18.2954, Penalty: 0.4123), Disc Loss: 0.0002, Faulty Rate: 0.2335
# Epoch 20/100 - Gen Loss: 25.3861 (Adv: 18.0640, Penalty: 0.3661), Disc Loss: 0.0002, Faulty Rate: 0.2330
# Epoch 21/100 - Gen Loss: 25.2812 (Adv: 19.0629, Penalty: 0.3109), Disc Loss: 0.0002, Faulty Rate: 0.2333
# Epoch 22/100 - Gen Loss: 25.6277 (Adv: 20.1474, Penalty: 0.2740), Disc Loss: 0.0002, Faulty Rate: 0.2280
# Epoch 23/100 - Gen Loss: 28.8032 (Adv: 24.0263, Penalty: 0.2388), Disc Loss: 0.0002, Faulty Rate: 0.2305
# Epoch 24/100 - Gen Loss: 26.7239 (Adv: 22.1816, Penalty: 0.2271), Disc Loss: 0.0001, Faulty Rate: 0.2227
# Epoch 25/100 - Gen Loss: 24.5283 (Adv: 20.7705, Penalty: 0.1879), Disc Loss: 0.0001, Faulty Rate: 0.2220
# Epoch 26/100 - Gen Loss: 23.2492 (Adv: 19.5560, Penalty: 0.1847), Disc Loss: 0.0001, Faulty Rate: 0.2200
# Epoch 27/100 - Gen Loss: 22.8521 (Adv: 19.4978, Penalty: 0.1677), Disc Loss: 0.0001, Faulty Rate: 0.2202
# Epoch 28/100 - Gen Loss: 22.5408 (Adv: 19.4207, Penalty: 0.1560), Disc Loss: 0.0001, Faulty Rate: 0.2222
# Epoch 29/100 - Gen Loss: 23.8467 (Adv: 20.4963, Penalty: 0.1675), Disc Loss: 0.0001, Faulty Rate: 0.2190
# Epoch 30/100 - Gen Loss: 25.6563 (Adv: 22.6928, Penalty: 0.1482), Disc Loss: 0.0001, Faulty Rate: 0.2122
# Epoch 31/100 - Gen Loss: 24.2390 (Adv: 20.9292, Penalty: 0.1655), Disc Loss: 0.0001, Faulty Rate: 0.2167
# Epoch 32/100 - Gen Loss: 23.4337 (Adv: 20.1620, Penalty: 0.1636), Disc Loss: 0.0001, Faulty Rate: 0.2122
# Epoch 33/100 - Gen Loss: 22.9918 (Adv: 19.8022, Penalty: 0.1595), Disc Loss: 0.0001, Faulty Rate: 0.2072
# Epoch 34/100 - Gen Loss: 23.9029 (Adv: 20.6400, Penalty: 0.1631), Disc Loss: 0.0001, Faulty Rate: 0.2100
# Epoch 35/100 - Gen Loss: 23.5663 (Adv: 20.0924, Penalty: 0.1737), Disc Loss: 0.0001, Faulty Rate: 0.2068
# Epoch 36/100 - Gen Loss: 23.9515 (Adv: 20.4068, Penalty: 0.1772), Disc Loss: 0.0001, Faulty Rate: 0.2042
# Epoch 37/100 - Gen Loss: 23.3753 (Adv: 19.6025, Penalty: 0.1886), Disc Loss: 0.0001, Faulty Rate: 0.2062
# Epoch 38/100 - Gen Loss: 23.7272 (Adv: 20.1684, Penalty: 0.1779), Disc Loss: 0.0001, Faulty Rate: 0.1898
# Epoch 39/100 - Gen Loss: 24.0096 (Adv: 20.0785, Penalty: 0.1966), Disc Loss: 0.0001, Faulty Rate: 0.1883
# Epoch 40/100 - Gen Loss: 23.7755 (Adv: 19.9420, Penalty: 0.1917), Disc Loss: 0.0001, Faulty Rate: 0.1898
# Epoch 41/100 - Gen Loss: 25.1104 (Adv: 21.2878, Penalty: 0.1911), Disc Loss: 0.0001, Faulty Rate: 0.1930
# Epoch 42/100 - Gen Loss: 35.9376 (Adv: 31.8770, Penalty: 0.2030), Disc Loss: 0.0002, Faulty Rate: 0.1817
# Epoch 43/100 - Gen Loss: 35.8851 (Adv: 31.7673, Penalty: 0.2059), Disc Loss: 0.0001, Faulty Rate: 0.1960
# Epoch 44/100 - Gen Loss: 29.3773 (Adv: 24.8291, Penalty: 0.2274), Disc Loss: 0.0001, Faulty Rate: 0.1845
# Epoch 45/100 - Gen Loss: 35.4384 (Adv: 30.6887, Penalty: 0.2375), Disc Loss: 0.0002, Faulty Rate: 0.1840
# Epoch 46/100 - Gen Loss: 34.3332 (Adv: 29.8783, Penalty: 0.2227), Disc Loss: 0.0001, Faulty Rate: 0.1885
# Epoch 47/100 - Gen Loss: 27.7739 (Adv: 23.1649, Penalty: 0.2304), Disc Loss: 0.0001, Faulty Rate: 0.1980
# Epoch 48/100 - Gen Loss: 25.8099 (Adv: 21.2885, Penalty: 0.2261), Disc Loss: 0.0001, Faulty Rate: 0.1955
# Epoch 49/100 - Gen Loss: 26.7451 (Adv: 22.1140, Penalty: 0.2316), Disc Loss: 0.0001, Faulty Rate: 0.1842
# Epoch 50/100 - Gen Loss: 25.8832 (Adv: 21.1022, Penalty: 0.2391), Disc Loss: 0.0001, Faulty Rate: 0.1795
# Epoch 51/100 - Gen Loss: 25.4126 (Adv: 20.6184, Penalty: 0.2397), Disc Loss: 0.0001, Faulty Rate: 0.1513
# Epoch 52/100 - Gen Loss: 23.9841 (Adv: 19.1918, Penalty: 0.2396), Disc Loss: 0.0001, Faulty Rate: 0.1402
# Epoch 53/100 - Gen Loss: 25.3528 (Adv: 19.4107, Penalty: 0.2971), Disc Loss: 0.0003, Faulty Rate: 0.1375
# Epoch 54/100 - Gen Loss: 26.4813 (Adv: 19.7396, Penalty: 0.3371), Disc Loss: 0.0003, Faulty Rate: 0.1743
# Epoch 55/100 - Gen Loss: 27.9938 (Adv: 21.1631, Penalty: 0.3415), Disc Loss: 0.0002, Faulty Rate: 0.2075
# Epoch 56/100 - Gen Loss: 27.4582 (Adv: 20.2945, Penalty: 0.3582), Disc Loss: 0.0002, Faulty Rate: 0.1867
# Epoch 57/100 - Gen Loss: 26.7578 (Adv: 18.4970, Penalty: 0.4130), Disc Loss: 0.0002, Faulty Rate: 0.1593
# Epoch 58/100 - Gen Loss: 47.2706 (Adv: 36.2504, Penalty: 0.5510), Disc Loss: 0.1217, Faulty Rate: 0.2470
# Epoch 59/100 - Gen Loss: 52.8943 (Adv: 25.8446, Penalty: 1.3525), Disc Loss: 0.0159, Faulty Rate: 0.2157
# Epoch 60/100 - Gen Loss: 49.8894 (Adv: 20.7071, Penalty: 1.4591), Disc Loss: 0.0038, Faulty Rate: 0.2668
# Epoch 61/100 - Gen Loss: 43.9622 (Adv: 17.9719, Penalty: 1.2995), Disc Loss: 0.0130, Faulty Rate: 0.3440
# Epoch 62/100 - Gen Loss: 37.7129 (Adv: 14.3342, Penalty: 1.1689), Disc Loss: 0.0011, Faulty Rate: 0.2348
# Epoch 63/100 - Gen Loss: 36.5750 (Adv: 15.0385, Penalty: 1.0768), Disc Loss: 0.0011, Faulty Rate: 0.2422
# Epoch 64/100 - Gen Loss: 36.9873 (Adv: 15.1981, Penalty: 1.0895), Disc Loss: 0.0033, Faulty Rate: 0.3473
# Epoch 65/100 - Gen Loss: 42.3175 (Adv: 12.5696, Penalty: 1.4874), Disc Loss: 0.0375, Faulty Rate: 0.3972
# Epoch 66/100 - Gen Loss: 42.4667 (Adv: 12.6277, Penalty: 1.4920), Disc Loss: 0.0194, Faulty Rate: 0.4230
# Epoch 67/100 - Gen Loss: 40.5725 (Adv: 11.2723, Penalty: 1.4650), Disc Loss: 0.0196, Faulty Rate: 0.4565
# Epoch 68/100 - Gen Loss: 39.6291 (Adv: 12.0968, Penalty: 1.3766), Disc Loss: 0.0184, Faulty Rate: 0.4283
# Epoch 69/100 - Gen Loss: 40.0592 (Adv: 12.8080, Penalty: 1.3626), Disc Loss: 0.0140, Faulty Rate: 0.4130
# Epoch 70/100 - Gen Loss: 41.2660 (Adv: 13.0625, Penalty: 1.4102), Disc Loss: 0.4502, Faulty Rate: 0.4335
# Epoch 71/100 - Gen Loss: 41.3673 (Adv: 11.6361, Penalty: 1.4866), Disc Loss: 0.0278, Faulty Rate: 0.4390
# Epoch 72/100 - Gen Loss: 39.0780 (Adv: 11.4306, Penalty: 1.3824), Disc Loss: 0.0212, Faulty Rate: 0.4187
# Epoch 73/100 - Gen Loss: 37.0638 (Adv: 10.1756, Penalty: 1.3444), Disc Loss: 0.0167, Faulty Rate: 0.4135
# Epoch 74/100 - Gen Loss: 35.3415 (Adv: 9.7170, Penalty: 1.2812), Disc Loss: 0.0247, Faulty Rate: 0.3980
# Epoch 75/100 - Gen Loss: 34.4146 (Adv: 9.6016, Penalty: 1.2407), Disc Loss: 0.0218, Faulty Rate: 0.4263
# Epoch 76/100 - Gen Loss: 33.3449 (Adv: 9.4953, Penalty: 1.1925), Disc Loss: 0.0199, Faulty Rate: 0.4173
# Epoch 77/100 - Gen Loss: 32.2729 (Adv: 8.9668, Penalty: 1.1653), Disc Loss: 0.0245, Faulty Rate: 0.4582
# Epoch 78/100 - Gen Loss: 32.2693 (Adv: 9.9981, Penalty: 1.1136), Disc Loss: 0.0210, Faulty Rate: 0.3733
# Epoch 79/100 - Gen Loss: 32.7780 (Adv: 10.7845, Penalty: 1.0997), Disc Loss: 0.0313, Faulty Rate: 0.4870
# Epoch 80/100 - Gen Loss: 32.1572 (Adv: 11.4541, Penalty: 1.0352), Disc Loss: 0.0235, Faulty Rate: 0.5055
# Epoch 81/100 - Gen Loss: 32.2357 (Adv: 11.4889, Penalty: 1.0373), Disc Loss: 0.0168, Faulty Rate: 0.5010
# Epoch 82/100 - Gen Loss: 33.2229 (Adv: 12.6299, Penalty: 1.0297), Disc Loss: 0.6849, Faulty Rate: 0.5280
# Epoch 83/100 - Gen Loss: 36.3051 (Adv: 13.8568, Penalty: 1.1224), Disc Loss: 0.2453, Faulty Rate: 0.3812
# Epoch 84/100 - Gen Loss: 32.4716 (Adv: 13.0678, Penalty: 0.9702), Disc Loss: 0.0407, Faulty Rate: 0.3692
# Epoch 85/100 - Gen Loss: 31.5729 (Adv: 12.9428, Penalty: 0.9315), Disc Loss: 0.0266, Faulty Rate: 0.3652
# Epoch 86/100 - Gen Loss: 30.4960 (Adv: 12.4606, Penalty: 0.9018), Disc Loss: 0.0200, Faulty Rate: 0.3887
# Epoch 87/100 - Gen Loss: 30.2810 (Adv: 12.3613, Penalty: 0.8960), Disc Loss: 0.0232, Faulty Rate: 0.3640
# Epoch 88/100 - Gen Loss: 30.0036 (Adv: 12.0769, Penalty: 0.8963), Disc Loss: 0.0139, Faulty Rate: 0.4170
# Epoch 89/100 - Gen Loss: 30.0039 (Adv: 11.9512, Penalty: 0.9026), Disc Loss: 0.0179, Faulty Rate: 0.4288
# Epoch 90/100 - Gen Loss: 30.1922 (Adv: 12.2943, Penalty: 0.8949), Disc Loss: 0.0271, Faulty Rate: 0.4602
# Epoch 91/100 - Gen Loss: 30.7666 (Adv: 13.1687, Penalty: 0.8799), Disc Loss: 0.0167, Faulty Rate: 0.4355
# Epoch 92/100 - Gen Loss: 29.6008 (Adv: 12.1816, Penalty: 0.8710), Disc Loss: 0.0127, Faulty Rate: 0.4308
# Epoch 93/100 - Gen Loss: 29.8889 (Adv: 12.6726, Penalty: 0.8608), Disc Loss: 0.0139, Faulty Rate: 0.3970
# Epoch 94/100 - Gen Loss: 31.6704 (Adv: 14.7961, Penalty: 0.8437), Disc Loss: 0.0079, Faulty Rate: 0.3730
# Epoch 95/100 - Gen Loss: 30.5929 (Adv: 13.8537, Penalty: 0.8370), Disc Loss: 0.0095, Faulty Rate: 0.3640
# Epoch 96/100 - Gen Loss: 30.3585 (Adv: 13.7290, Penalty: 0.8315), Disc Loss: 0.0078, Faulty Rate: 0.4405
# Epoch 97/100 - Gen Loss: 30.7517 (Adv: 14.2718, Penalty: 0.8240), Disc Loss: 0.0083, Faulty Rate: 0.4202
# Epoch 98/100 - Gen Loss: 31.3971 (Adv: 14.9997, Penalty: 0.8199), Disc Loss: 0.0088, Faulty Rate: 0.4263
# Epoch 99/100 - Gen Loss: 31.6678 (Adv: 15.3099, Penalty: 0.8179), Disc Loss: 0.0229, Faulty Rate: 0.4310
# Epoch 100/100 - Gen Loss: 32.9879 (Adv: 16.8721, Penalty: 0.8058), Disc Loss: 0.0067, Faulty Rate: 0.3810
