# %%
from dataclasses import dataclass

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# ### Set seeds for reproducibility

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Check for GPU availability

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"Using GPU: {gpus}")
else:
    print("Using CPU")
# Out:
# Using GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
lob_features = [
    "b0p", "b1p", "b2p", "b3p", "b4p", "b5p", "b6p", "b7p", "b8p", "b9p",
    "b0q", "b1q", "b2q", "b3q", "b4q", "b5q", "b6q", "b7q", "b8q", "b9q",
    "a0p", "a1p", "a2p", "a3p", "a4p", "a5p", "a6p", "a7p", "a8p", "a9p",
    "a0q", "a1q", "a2q", "a3q", "a4q", "a5q", "a6q", "a7q", "a8q", "a9q"
]

# %%
@dataclass
class Config:
    z_dim = 2*100  # Dimension of random noise
    batch_size = 64
    learning_rate_g = 0.0002
    learning_rate_d = 0.0002
    epochs = 100
    penalty_weight = 5
    sample_size = 5000
    faulty_rate_weight = 20

config = Config()

# %% [markdown]
# ### Load and preprocess LOB data

# %%
file_path = "E:\DSA5204 Project\DSA5204-Group-9\lob\BTCUSDT-lob.parq"
df = pd.read_parquet(file_path, engine="pyarrow")

print(f"The legnth for the dataframe is {len(df)}")
# Out:
# The legnth for the dataframe is 189760

# %%
df.iloc[:, 25:35].head()
# Out:
#        a0p      a1p      a2p      a3p      a4p      a5p      a6p      a7p  \
# 0  95180.0  95180.1  95180.2  95180.6  95180.7  95180.8  95181.5  95181.6
# 1  95180.0  95180.1  95180.6  95180.7  95180.8  95181.5  95181.6  95181.8
# 2  95180.0  95180.1  95180.4  95180.6  95180.7  95180.8  95181.5  95181.6
# 3  95180.0  95180.1  95180.4  95180.6  95180.7  95180.8  95181.5  95181.6
# 4  95180.0  95180.1  95180.4  95180.6  95180.7  95180.8  95181.5  95181.6
#
#        a8p      a9p
# 0  95181.8  95181.9
# 1  95181.9  95182.0
# 2  95181.8  95181.9
# 3  95181.8  95181.9
# 4  95181.8  95181.9

# %%
df = df.dropna(subset=lob_features).sample(n=config.sample_size, random_state=42)

# %%
#scaler = MinMaxScaler()
#lob_data = scaler.fit_transform(df[lob_features].values).astype(np.float32) #(5000, 40)
# Remove min max scaler.
lob_data = df[lob_features].values.astype(np.float32) #(5000, 40)
lob_dataset = tf.data.Dataset.from_tensor_slices(lob_data).batch(config.batch_size)

#lob_dataset: TensorFlow Dataset object

# %%
for batch in lob_dataset.take(1):
    print(f"Dimension of lob_dataset: {batch.shape}")
# Out:
# Dimension of lob_dataset: (64, 40)

# %% [markdown]
# ### Generator

# %%
class Generator(models.Model):
    def __init__(self, config):
        super(Generator, self).__init__()
        self.config = config
        self.z_dim = config.z_dim
        
        # For price vector (20 feature: 10 bid + 10 ask)
        self.price_dense = layers.Dense(40)
        
        # For quantity vector generation, ensure all are positive.
        self.q_dense1 = layers.Dense(128, activation='relu')
        # self.q_dense2 = layers.Dense(64, activation='relu')
        # self.q_dense3 = layers.Dense(32, activation='relu')
        self.q_output = layers.Dense(20)

    def call(self, inputs, training=True):
        # Split noise into two parts: one for price, one for quantity
        z_price, z_volume = tf.split(inputs, num_or_size_splits=2, axis=1)
        
        # Generate price vector
        price_output = self.price_dense(z_price)
        bid_prices = price_output[:, :10]
        ask_prices = price_output[:, 10:20]
        
        # Quantity vector generation
        x_q = self.q_dense1(z_volume)
        # x_q = self.q_dense2(x_q)
        # x_q = self.q_dense3(x_q)
        quantity_output = self.q_output(x_q)
        bid_quantities = quantity_output[:, :10]
        ask_quantities = quantity_output[:, 10:20]
        
        # Combine: [b0p...b9p, b0q...b9q, a0p...a9p, a0q...a9q]
        combined = tf.concat([bid_prices, bid_quantities, ask_prices, ask_quantities], axis=1)
        return combined

# %% [markdown]
# ### Minibatch Discriminator

# %%
# Minibatch Discrimination code
class MinibatchDiscrimination(layers.Layer):
    """Minibatch discrimination layer to prevent mode collapse"""

    def __init__(self, num_kernels=100, dim_per_kernel=5, **kwargs):
        super(MinibatchDiscrimination, self).__init__(**kwargs)
        self.num_kernels = num_kernels
        self.dim_per_kernel = dim_per_kernel

    def build(self, input_shape):
        #Defines a trainable weight (self.kernel) of shape (input_dim, num_kernels, dim_per_kernel)
        self.input_dim = input_shape[1] #Stores the number of features in the input tensor.
        kernel_shape = (self.input_dim, self.num_kernels, self.dim_per_kernel) #Shape of the kernel tensor
        initializer = tf.random_normal_initializer(stddev=0.02)
        self.kernel = self.add_weight(
            shape=kernel_shape,
            initializer=initializer,
            name='kernel',
            trainable=True
        )
        super(MinibatchDiscrimination, self).build(input_shape)

    def call(self, inputs, **kwargs):
        #Computes a projection of inputs using self.kernel.
        #If inputs has shape (batch_size, input_dim),
        #And kernel has shape (input_dim, num_kernels, dim_per_kernel),
        #Then activation will have shape (batch_size, num_kernels, dim_per_kernel).
        #Got from dot product.
        activation = tf.tensordot(inputs, self.kernel, axes=[[1], [0]])
        
        #Expands dimensions to compare all batch samples.
        expanded_act = tf.expand_dims(activation, 3)
        transposed_act = tf.expand_dims(tf.transpose(activation, [1, 2, 0]), 0)

        diff = expanded_act - transposed_act #
        abs_diff = tf.reduce_sum(tf.abs(diff), 2) #Computes the absolute differences between all pairs of samples.

        #Apply mask to avoid comparing a sample with itself.
        batch_size = tf.shape(inputs)[0]
        mask = 1.0 - tf.eye(batch_size) 
        #Creates an identity matrix (tf.eye(batch_size)), which has 1s on the diagonal and subtracts it from 1.0. Ensures that the diagonal is 0.
        mask = tf.expand_dims(mask, 1)

        #Expands dimensions to match abs_diff.
        if mask.shape.ndims != abs_diff.shape.ndims:
            mask = tf.reshape(mask, [-1, mask.shape[1], batch_size])

        exp = tf.exp(-abs_diff) * mask
        minibatch_features = tf.reduce_sum(exp, 2)

        return tf.concat([inputs, minibatch_features], axis=1)

# %% [markdown]
# The final shape is (batch_size, input_dim + num_kernels).

# %% [markdown]
# ### Discriminator

# %% [markdown]
# No batch normalization for discriminator as BatchNorm normalizes across the batch, which may leak information between examples.

# %%
class Discriminator(models.Model):
    """Simple Discriminator for classifying real vs fake feature vectors with financial constraints"""
    def __init__(self, config, use_minibatch_discrimination=False):
        super(Discriminator, self).__init__()
        self.config = config
        self.use_minibatch_discrimination = use_minibatch_discrimination  # Store the flag
        
        # Price Stream:
        self.price_dense = layers.Dense(20) #No activation
        
        # Quantity Stream:
        self.quantity_dense = layers.Dense(20, activation = 'relu')
        
        # Shared layers after combining both streams
        self.dense1 = layers.Dense(512)
        self.leaky1 = layers.LeakyReLU(alpha=0.2)
        
        # self.dense2 = layers.Dense(256)
        # self.leaky2 = layers.LeakyReLU(alpha=0.2) 
          
        if use_minibatch_discrimination:
            self.minibatch_layer = MinibatchDiscrimination(num_kernels=100, dim_per_kernel=5)

        # self.dense3 = layers.Dense(128)
        # self.leaky3 = layers.LeakyReLU(alpha=0.2)

        # self.dense4 = layers.Dense(64)
        # self.leaky4 = layers.LeakyReLU(alpha=0.2)
        
        self.output_layer = layers.Dense(1) #Just a real/ fake classification
    
    def call(self, input, training=True):
        # Split input: [b0p..b9p, b0q..b9q, a0p..a9p, a0q..a9q]
        bid_price = input[:, :10]
        bid_quantity = input[:, 10:20]
        ask_price = input[:, 20:30]
        ask_quantity = input[:, 30:40]
        
        # Combine price and quantity vectors:
        price_vector = tf.concat([bid_price, ask_price], axis=1)
        quantity_vector = tf.concat([bid_quantity, ask_quantity], axis=1)
        
        # Apply respective processing
        price_out = self.price_dense(price_vector)
        quantity_out = self.quantity_dense(quantity_vector)
        
        # Combine processed features
        x = tf.concat([price_out, quantity_out], axis=1)
        
        x = self.dense1(x)
        x = self.leaky1(x)
        
        # x = self.dense2(x)
        # x = self.leaky2(x)
        
        if self.use_minibatch_discrimination:
            x = self.minibatch_layer(x)

        # x = self.dense3(x)
        # x = self.leaky3(x)

        # x = self.dense4(x)
        # x = self.leaky4(x)

        output = self.output_layer(x)

        return output

# %%
class SimpleGAN:
    """Simplest GAN using a Generator and a Discriminator.
       Includes differentiable soft penalty for LOB rules.
    """
    def __init__(self, config, use_minibatch_discrimination=False):
        self.config = config
        self.generator = Generator(config)
        self.discriminator = Discriminator(config, use_minibatch_discrimination=use_minibatch_discrimination)
        self.gen_optimizer = tf.keras.optimizers.Adam(config.learning_rate_g)
        self.disc_optimizer = tf.keras.optimizers.Adam(config.learning_rate_d)
        self.fixed_noise = tf.random.normal([16, config.z_dim])

    def generator_loss(self, fake_output, generated_lob):
        target = tf.ones_like(fake_output)
        adv_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(target, fake_output, from_logits=True))
        penalty = differentiable_faulty_penalty(generated_lob)
        penalty_loss = tf.reduce_mean(penalty)
        total_loss = adv_loss + self.config.faulty_rate_weight * penalty_loss
        return total_loss

    def discriminator_loss(self, real_output, fake_output):
        real_labels = tf.ones_like(real_output)
        fake_labels = tf.zeros_like(fake_output)
        real_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(real_labels, real_output, from_logits=True))
        fake_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(fake_labels, fake_output, from_logits=True))
        return real_loss + fake_loss

    @tf.function
    def train_step(self, real_matrices):
        batch_size = tf.shape(real_matrices)[0]
        noise = tf.random.normal([batch_size, self.config.z_dim])

        with tf.GradientTape() as disc_tape:
            fake_matrices = self.generator(noise, training=True)
            real_output = self.discriminator(real_matrices, training=True)
            fake_output = self.discriminator(fake_matrices, training=True)
            disc_loss = self.discriminator_loss(real_output, fake_output)

        disc_gradients = disc_tape.gradient(disc_loss, self.discriminator.trainable_variables)
        self.disc_optimizer.apply_gradients(zip(disc_gradients, self.discriminator.trainable_variables))

        with tf.GradientTape() as gen_tape:
            fake_matrices = self.generator(noise, training=True)
            fake_output = self.discriminator(fake_matrices, training=True)
            gen_loss = self.generator_loss(fake_output, fake_matrices)

        gen_gradients = gen_tape.gradient(gen_loss, self.generator.trainable_variables)
        self.gen_optimizer.apply_gradients(zip(gen_gradients, self.generator.trainable_variables))

        return {
            "gen_loss": gen_loss,
            "disc_loss": disc_loss
        }

# %% [markdown]
# ### Reasonability Check functions:

# %%
def differentiable_faulty_penalty(lob_tensor):
    """Differentiable soft constraint penalty for LOB rules (usable in generator loss)."""

    bid_prices = lob_tensor[:, :10]        # b0p - b9p
    bid_quantities = lob_tensor[:, 10:20]  # b0q - b9q
    ask_prices = lob_tensor[:, 20:30]      # a0p - a9p
    ask_quantities = lob_tensor[:, 30:40]  # a0q - a9q

    # 1. Soft penalty for best_bid >= best_ask (should be best_bid < best_ask)
    best_bid = bid_prices[:, -1]  # b9p
    best_ask = ask_prices[:, 0]  # a0p
    spread_violation = tf.nn.softplus(best_bid - best_ask)  # positive when constraint is violated

    # 2. Bid prices should decrease: b0 > b1 > ... > b9
    bid_diff = bid_prices[:, :-1] - bid_prices[:, 1:]
    bid_order_penalty = tf.reduce_sum(tf.nn.relu(-bid_diff), axis=1)

    # 3. Ask prices should increase: a0 < a1 < ... < a9
    ask_diff = ask_prices[:, 1:] - ask_prices[:, :-1]
    ask_order_penalty = tf.reduce_sum(tf.nn.relu(-ask_diff), axis=1)

    # 4. Volumes must be >= 0
    bid_volume_penalty = tf.reduce_sum(tf.nn.relu(-bid_quantities), axis=1)
    ask_volume_penalty = tf.reduce_sum(tf.nn.relu(-ask_quantities), axis=1)

    # Combine all penalties per sample
    total_penalty = spread_violation + bid_order_penalty + ask_order_penalty + bid_volume_penalty + ask_volume_penalty

    return total_penalty  # Shape: (batch_size,)

# %% [markdown]
# differentiable_faulty_penalty: Act as a differentiable penalty function.
#
# Why this works?
#
#
# - Replaces non-differentiable hard constraints with smooth or subdifferentiable approximations that are compatible with backpropagation and gradient-based optimization.
#
#
#  Spread Violation
# - $softplus(x) = log(1 + exp(x))$ is a smooth, differentiable approximation of ```relu(x)```.
#
#
#  Bid/ Ask Price Ordering
#  - ```tf.nn.relu``` is subdifferentiable. That’s sufficient for most optimizers (like Adam) in practice.
#
#
#  Volume Positivity
#  - ```relu``` is again subdifferentiable and well-handled in Tensorflow.

# %%
def compute_faulty_rate(lob_tensor):
    """Calculates the faulty rate for synthetic LOB data using TensorFlow tensors."""
    
    bid_prices = lob_tensor[:, :10]  # First 10 columns are bid prices
    ask_prices = lob_tensor[:, 20:30]  # Columns 20-30 are ask prices
    bid_quantities = lob_tensor[:, 10:20]  # Columns 10-20 are bid quantities
    ask_quantities = lob_tensor[:, 30:40]  # Columns 30-40 are ask quantities

    faulty_count = tf.zeros(1, dtype=tf.float32)  # Initialize faulty count

    # 1. Ensure best bid price < best ask price (b0p < a0p)
    max_bid = tf.reduce_max(bid_prices, axis=1)  # Get the highest bid
    min_ask = tf.reduce_min(ask_prices, axis=1)  # Get the lowest ask
    faulty_count += tf.reduce_sum(tf.cast(max_bid >= min_ask, tf.float32))  # Count violations

    # 2. Bid prices should be in descending order (b0p > b1p > ...)
    faulty_count += tf.reduce_sum(tf.cast(tf.experimental.numpy.diff(bid_prices, axis=1) >= 0, tf.float32))

    # 3. Ask prices should be in ascending order (a0p < a1p < ...)
    faulty_count += tf.reduce_sum(tf.cast(tf.experimental.numpy.diff(ask_prices, axis=1) <= 0, tf.float32))

    # 4. Bid and ask quantities should be non-negative
    faulty_count += tf.reduce_sum(tf.cast(bid_quantities < 0, tf.float32))
    faulty_count += tf.reduce_sum(tf.cast(ask_quantities < 0, tf.float32))
    faulty_count += tf.reduce_sum(tf.cast(bid_prices < 0, tf.float32))
    faulty_count += tf.reduce_sum(tf.cast(ask_prices < 0, tf.float32))

    # Compute faulty rate as a percentage of all elements
    total_elements = tf.size(lob_tensor, out_type=tf.float32)
    faulty_rate = faulty_count / total_elements  # Returns a TensorFlow tensor

    return faulty_rate.numpy()  # Convert to NumPy for further processing

# %% [markdown]
# ### Function to compute the faulty stats to understand the quality of the generated LOB

# %%
def compute_faulty_stats(lob_tensor):
    if not isinstance(lob_tensor, tf.Tensor):
        lob_tensor = tf.convert_to_tensor(lob_tensor, dtype=tf.float32)

    # Split into bid/ask prices and quantities
    bid_prices = lob_tensor[:, :10]        # b0p - b9p
    bid_quantities = lob_tensor[:, 10:20]  # b0q - b9q
    ask_prices = lob_tensor[:, 20:30]      # a0p - a9p
    ask_quantities = lob_tensor[:, 30:40]  # a0q - a9q

    # Combine quantities
    all_quantities = tf.concat([bid_quantities, ask_quantities], axis=1)

    # Count of negative quantities
    neg_qty_mask = all_quantities < 0
    neg_qty_count = tf.reduce_sum(tf.cast(neg_qty_mask, tf.float32))

    # Sum of negative quantities
    neg_qty_sum = tf.reduce_sum(tf.where(neg_qty_mask, all_quantities, tf.zeros_like(all_quantities)))

    # Count of ask prices that are lower than previous (should be ascending)
    ask_diff_prev = ask_prices[:, 1:] - ask_prices[:, :-1]
    lower_prev_count = tf.reduce_sum(tf.cast(ask_diff_prev < 0, tf.float32))

    # Count of bid prices that are higher than next (should be descending)
    bid_diff_next = bid_prices[:, :-1] - bid_prices[:, 1:]
    higher_next_count = tf.reduce_sum(tf.cast(bid_diff_next < 0, tf.float32))

    # Sum of max(0, price[i+1] - price[i]) for all prices (violations of ascending)
    all_prices = tf.concat([bid_prices, ask_prices], axis=1)
    diff_positive_sum = tf.reduce_sum(tf.nn.relu(all_prices[:, 1:] - all_prices[:, :-1]))

    # Sum of max(0, price[i] - price[i+1]) for all prices (violations of descending)
    diff_negative_sum = tf.reduce_sum(tf.nn.relu(all_prices[:, :-1] - all_prices[:, 1:]))

    return {
        "neg_qty_count": float(neg_qty_count.numpy()),
        "neg_qty_sum": float(neg_qty_sum.numpy()),
        "lower_prev_count": float(lower_prev_count.numpy()),
        "higher_next_count": float(higher_next_count.numpy()),
        "diff_positive_sum": float(diff_positive_sum.numpy()),
        "diff_negative_sum": float(diff_negative_sum.numpy()),
    }

# %% [markdown]
# ### Records down the faulty rate at the end of each epoch and plot the change.

# %%
def plot_training_trends(gen_losses, 
                         disc_losses, 
                         faulty_rates, 
                         neg_qty_count_history,
                         neg_qty_sum_history,
                         lower_prev_count_history,
                         higher_next_count_history,
                         diff_positive_sum_history,
                         diff_negative_sum_history,
                         label_prefix="GAN"):

    epochs_arr = np.arange(1, len(gen_losses) + 1)

    fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(nrows=7, ncols=1, figsize=(12, 16), sharex=True)

    # Plot 1: Generator Loss
    ax1.plot(epochs_arr, gen_losses, color='tab:blue', marker='o')
    ax1.set_ylabel("Generator Loss")
    ax1.set_title(f"{label_prefix} - Generator Loss")
    ax1.grid(True)

    # Plot 2: Discriminator Loss
    ax2.plot(epochs_arr, disc_losses, color='tab:green', marker='s')
    ax2.set_ylabel("Discriminator Loss")
    ax2.set_title(f"{label_prefix} - Discriminator Loss")
    ax2.grid(True)

    # Plot 3: Faulty Rate
    ax3.plot(epochs_arr, faulty_rates, color='tab:red', marker='^')
    ax3.set_ylabel("Faulty Rate")
    ax3.set_title(f"{label_prefix} - Faulty Rate")
    ax3.grid(True)

    # Plot 4: Negative Quantity Count
    ax4.plot(epochs_arr, neg_qty_count_history, color='tab:orange', marker='x')
    ax4.set_ylabel("Neg Qty Count")
    ax4.set_title(f"{label_prefix} - Negative Quantity Count")
    ax4.grid(True)

    # Plot 5: Negative Quantity Sum
    ax5.plot(epochs_arr, neg_qty_sum_history, color='tab:purple', marker='d')
    ax5.set_ylabel("Neg Qty Sum")
    ax5.set_title(f"{label_prefix} - Negative Quantity Sum")
    ax5.grid(True)

    # Plot 6: Price Order Violations (Ask↓ and Bid↑ counts)
    ax6.plot(epochs_arr, lower_prev_count_history, label="Lower Prev Count (Ask↓)", marker='v', color='brown')
    ax6.plot(epochs_arr, higher_next_count_history, label="Higher Next Count (Bid↑)", marker='>', color='pink')
    ax6.set_ylabel("Violation Counts")
    ax6.set_title(f"{label_prefix} - Price Order Violations")
    ax6.legend()
    ax6.grid(True)

    # Plot 7: Price Differences (Smoothness)
    ax7.plot(epochs_arr, diff_positive_sum_history, label="Sum max(0, p[i+1]-p[i])", marker='*', color='cyan')
    ax7.plot(epochs_arr, diff_negative_sum_history, label="Sum max(0, p[i]-p[i+1])", marker='*', color='magenta')
    ax7.set_ylabel("Price Diff Sum")
    ax7.set_title(f"{label_prefix} - Price Differences")
    ax7.set_xlabel("Epoch")
    ax7.legend()
    ax7.grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Train normal

# %%
gan = SimpleGAN(config, use_minibatch_discrimination=False)

# History tracking
gen_loss_history = []
disc_loss_history = []
faulty_rate_history = []

# Refined: Faulty stats tracking
neg_qty_count_history = []
neg_qty_sum_history = []
lower_prev_count_history = []     # Ask price
higher_next_count_history = []    # Bid price
diff_positive_sum_history = []
diff_negative_sum_history = []

for epoch in range(config.epochs):
    epoch_gen_loss = 0.0
    epoch_disc_loss = 0.0
    num_batches = 0

    for batch in lob_dataset:
        metrics = gan.train_step(batch)
        epoch_gen_loss += metrics['gen_loss']
        epoch_disc_loss += metrics['disc_loss']
        num_batches += 1

    avg_gen_loss = epoch_gen_loss / num_batches
    avg_disc_loss = epoch_disc_loss / num_batches

    gen_loss_history.append(float(avg_gen_loss))
    disc_loss_history.append(float(avg_disc_loss))

    # Generate LOB samples
    noise = tf.random.normal([100, config.z_dim])
    generated_samples = gan.generator(noise, training=False)

    # Faulty rate
    faulty_rate = compute_faulty_rate(generated_samples)
    faulty_rate_scalar = float(faulty_rate.item())
    faulty_rate_history.append(faulty_rate_scalar)

    # Faulty stats
    stats = compute_faulty_stats(generated_samples)
    neg_qty_count_history.append(stats["neg_qty_count"])
    neg_qty_sum_history.append(stats["neg_qty_sum"])
    lower_prev_count_history.append(stats["lower_prev_count"])
    higher_next_count_history.append(stats["higher_next_count"])
    diff_positive_sum_history.append(stats["diff_positive_sum"])
    diff_negative_sum_history.append(stats["diff_negative_sum"])

    print(f"Epoch {epoch+1}/{config.epochs} - "
          f"Gen Loss: {avg_gen_loss:.4f}, "
          f"Disc Loss: {avg_disc_loss:.4f}, "
          f"Faulty Rate: {faulty_rate_scalar:.4f}, ")

plot_training_trends(
    gen_loss_history, 
    disc_loss_history, 
    faulty_rate_history, 
    neg_qty_count_history,
    neg_qty_sum_history,
    lower_prev_count_history,
    higher_next_count_history,
    diff_positive_sum_history,
    diff_negative_sum_history,
    label_prefix="GAN"
)
# Out:
# Epoch 1/100 - Gen Loss: 312.3118, Disc Loss: 56.2153, Faulty Rate: 0.5730,
# Epoch 2/100 - Gen Loss: 251.8599, Disc Loss: 0.0611, Faulty Rate: 0.5360,
# Epoch 3/100 - Gen Loss: 226.3275, Disc Loss: 0.0106, Faulty Rate: 0.5178,
# Epoch 4/100 - Gen Loss: 205.4603, Disc Loss: 0.0044, Faulty Rate: 0.5235,
# Epoch 5/100 - Gen Loss: 188.0506, Disc Loss: 0.0027, Faulty Rate: 0.5098,
# Epoch 6/100 - Gen Loss: 170.7158, Disc Loss: 0.0019, Faulty Rate: 0.5020,
# Epoch 7/100 - Gen Loss: 153.8456, Disc Loss: 0.0016, Faulty Rate: 0.5123,
# Epoch 8/100 - Gen Loss: 136.9273, Disc Loss: 0.0015, Faulty Rate: 0.4915,
# Epoch 9/100 - Gen Loss: 121.9465, Disc Loss: 0.0015, Faulty Rate: 0.4983,
# Epoch 10/100 - Gen Loss: 107.3400, Disc Loss: 0.0013, Faulty Rate: 0.5075,
# Epoch 11/100 - Gen Loss: 94.5269, Disc Loss: 0.0013, Faulty Rate: 0.5070,
# Epoch 12/100 - Gen Loss: 81.9471, Disc Loss: 0.0012, Faulty Rate: 0.4848,
# Epoch 13/100 - Gen Loss: 71.3381, Disc Loss: 0.0012, Faulty Rate: 0.4885,
# Epoch 14/100 - Gen Loss: 62.1409, Disc Loss: 0.0011, Faulty Rate: 0.4897,
# Epoch 15/100 - Gen Loss: 54.1631, Disc Loss: 0.0011, Faulty Rate: 0.4590,
# Epoch 16/100 - Gen Loss: 47.9335, Disc Loss: 0.0010, Faulty Rate: 0.4710,
# Epoch 17/100 - Gen Loss: 42.6967, Disc Loss: 0.0010, Faulty Rate: 0.4577,
# Epoch 18/100 - Gen Loss: 38.3556, Disc Loss: 0.0010, Faulty Rate: 0.4425,
# Epoch 19/100 - Gen Loss: 35.3797, Disc Loss: 0.0009, Faulty Rate: 0.4067,
# Epoch 20/100 - Gen Loss: 32.3270, Disc Loss: 0.0009, Faulty Rate: 0.4283,
# Epoch 21/100 - Gen Loss: 30.0224, Disc Loss: 0.0008, Faulty Rate: 0.4108,
# Epoch 22/100 - Gen Loss: 27.9057, Disc Loss: 0.0008, Faulty Rate: 0.3980,
# Epoch 23/100 - Gen Loss: 26.1969, Disc Loss: 0.0007, Faulty Rate: 0.3895,
# Epoch 24/100 - Gen Loss: 25.0639, Disc Loss: 0.0007, Faulty Rate: 0.3465,
# Epoch 25/100 - Gen Loss: 23.7284, Disc Loss: 0.0007, Faulty Rate: 0.3787,
# Epoch 26/100 - Gen Loss: 22.8390, Disc Loss: 0.0007, Faulty Rate: 0.3632,
# Epoch 27/100 - Gen Loss: 22.2732, Disc Loss: 0.0007, Faulty Rate: 0.3415,
# Epoch 28/100 - Gen Loss: 21.5875, Disc Loss: 0.0007, Faulty Rate: 0.3417,
# Epoch 29/100 - Gen Loss: 21.0860, Disc Loss: 0.0008, Faulty Rate: 0.3270,
# Epoch 30/100 - Gen Loss: 20.7363, Disc Loss: 0.0008, Faulty Rate: 0.3020,
# Epoch 31/100 - Gen Loss: 20.3497, Disc Loss: 0.0008, Faulty Rate: 0.3047,
# Epoch 32/100 - Gen Loss: 19.9478, Disc Loss: 0.0008, Faulty Rate: 0.3223,
# Epoch 33/100 - Gen Loss: 19.7328, Disc Loss: 0.0008, Faulty Rate: 0.2735,
# Epoch 34/100 - Gen Loss: 19.4894, Disc Loss: 0.0008, Faulty Rate: 0.2850,
# Epoch 35/100 - Gen Loss: 19.1995, Disc Loss: 0.0008, Faulty Rate: 0.2932,
# Epoch 36/100 - Gen Loss: 19.0481, Disc Loss: 0.0008, Faulty Rate: 0.2767,
# Epoch 37/100 - Gen Loss: 18.8013, Disc Loss: 0.0007, Faulty Rate: 0.2935,
# Epoch 38/100 - Gen Loss: 18.6089, Disc Loss: 0.0008, Faulty Rate: 0.2840,
# Epoch 39/100 - Gen Loss: 18.5371, Disc Loss: 0.0007, Faulty Rate: 0.2553,
# Epoch 40/100 - Gen Loss: 18.2940, Disc Loss: 0.0008, Faulty Rate: 0.3013,
# Epoch 41/100 - Gen Loss: 18.0591, Disc Loss: 0.0008, Faulty Rate: 0.2562,
# Epoch 42/100 - Gen Loss: 17.9386, Disc Loss: 0.0007, Faulty Rate: 0.2715,
# Epoch 43/100 - Gen Loss: 17.7471, Disc Loss: 0.0007, Faulty Rate: 0.2485,
# Epoch 44/100 - Gen Loss: 17.5179, Disc Loss: 0.0007, Faulty Rate: 0.2652,
# Epoch 45/100 - Gen Loss: 17.3614, Disc Loss: 0.0007, Faulty Rate: 0.2587,
# Epoch 46/100 - Gen Loss: 17.1711, Disc Loss: 0.0007, Faulty Rate: 0.2690,
# Epoch 47/100 - Gen Loss: 17.0191, Disc Loss: 0.0007, Faulty Rate: 0.2590,
# Epoch 48/100 - Gen Loss: 16.7938, Disc Loss: 0.0006, Faulty Rate: 0.2925,
# Epoch 49/100 - Gen Loss: 16.6495, Disc Loss: 0.0006, Faulty Rate: 0.2338,
# Epoch 50/100 - Gen Loss: 16.4534, Disc Loss: 0.0006, Faulty Rate: 0.2727,
# Epoch 51/100 - Gen Loss: 16.3166, Disc Loss: 0.0006, Faulty Rate: 0.2755,
# Epoch 52/100 - Gen Loss: 16.1807, Disc Loss: 0.0005, Faulty Rate: 0.2455,
# Epoch 53/100 - Gen Loss: 16.0208, Disc Loss: 0.0005, Faulty Rate: 0.2562,
# Epoch 54/100 - Gen Loss: 15.8641, Disc Loss: 0.0005, Faulty Rate: 0.2655,
# Epoch 55/100 - Gen Loss: 15.7411, Disc Loss: 0.0005, Faulty Rate: 0.2657,
# Epoch 56/100 - Gen Loss: 15.5727, Disc Loss: 0.0004, Faulty Rate: 0.2525,
# Epoch 57/100 - Gen Loss: 15.4622, Disc Loss: 0.0004, Faulty Rate: 0.2567,
# Epoch 58/100 - Gen Loss: 15.3041, Disc Loss: 0.0004, Faulty Rate: 0.2562,
# Epoch 59/100 - Gen Loss: 15.2339, Disc Loss: 0.0003, Faulty Rate: 0.2640,
# Epoch 60/100 - Gen Loss: 15.1216, Disc Loss: 0.0003, Faulty Rate: 0.2438,
# Epoch 61/100 - Gen Loss: 14.9953, Disc Loss: 0.0003, Faulty Rate: 0.2528,
# Epoch 62/100 - Gen Loss: 14.9072, Disc Loss: 0.0003, Faulty Rate: 0.2520,
# Epoch 63/100 - Gen Loss: 14.8145, Disc Loss: 0.0002, Faulty Rate: 0.2522,
# Epoch 64/100 - Gen Loss: 14.7749, Disc Loss: 0.0002, Faulty Rate: 0.2695,
# Epoch 65/100 - Gen Loss: 14.6966, Disc Loss: 0.0002, Faulty Rate: 0.2600,
# Epoch 66/100 - Gen Loss: 14.6468, Disc Loss: 0.0002, Faulty Rate: 0.2550,
# Epoch 67/100 - Gen Loss: 14.6213, Disc Loss: 0.0002, Faulty Rate: 0.2470,
# Epoch 68/100 - Gen Loss: 14.5698, Disc Loss: 0.0001, Faulty Rate: 0.2725,
# Epoch 69/100 - Gen Loss: 14.5638, Disc Loss: 0.0001, Faulty Rate: 0.2485,
# Epoch 70/100 - Gen Loss: 14.5134, Disc Loss: 0.0001, Faulty Rate: 0.2488,
# Epoch 71/100 - Gen Loss: 14.5131, Disc Loss: 0.0001, Faulty Rate: 0.2745,
# Epoch 72/100 - Gen Loss: 14.5098, Disc Loss: 0.0001, Faulty Rate: 0.2630,
# Epoch 73/100 - Gen Loss: 14.5058, Disc Loss: 0.0001, Faulty Rate: 0.2663,
# Epoch 74/100 - Gen Loss: 14.4907, Disc Loss: 0.0001, Faulty Rate: 0.2660,
# Epoch 75/100 - Gen Loss: 14.5088, Disc Loss: 0.0001, Faulty Rate: 0.2565,
# Epoch 76/100 - Gen Loss: 14.5076, Disc Loss: 0.0001, Faulty Rate: 0.3077,
# Epoch 77/100 - Gen Loss: 14.5111, Disc Loss: 0.0001, Faulty Rate: 0.2200,
# Epoch 78/100 - Gen Loss: 14.5200, Disc Loss: 0.0001, Faulty Rate: 0.2522,
# Epoch 79/100 - Gen Loss: 14.5223, Disc Loss: 0.0001, Faulty Rate: 0.2790,
# Epoch 80/100 - Gen Loss: 14.5448, Disc Loss: 0.0000, Faulty Rate: 0.2612,
# Epoch 81/100 - Gen Loss: 14.5469, Disc Loss: 0.0000, Faulty Rate: 0.2777,
# Epoch 82/100 - Gen Loss: 14.5586, Disc Loss: 0.0000, Faulty Rate: 0.2940,
# Epoch 83/100 - Gen Loss: 14.5717, Disc Loss: 0.0000, Faulty Rate: 0.2517,
# Epoch 84/100 - Gen Loss: 14.5804, Disc Loss: 0.0000, Faulty Rate: 0.2395,
# Epoch 85/100 - Gen Loss: 14.5903, Disc Loss: 0.0000, Faulty Rate: 0.3015,
# Epoch 86/100 - Gen Loss: 14.6049, Disc Loss: 0.0000, Faulty Rate: 0.2375,
# Epoch 87/100 - Gen Loss: 14.6016, Disc Loss: 0.0000, Faulty Rate: 0.2138,
# Epoch 88/100 - Gen Loss: 14.6121, Disc Loss: 0.0000, Faulty Rate: 0.2663,
# Epoch 89/100 - Gen Loss: 14.6249, Disc Loss: 0.0000, Faulty Rate: 0.2503,
# Epoch 90/100 - Gen Loss: 14.6317, Disc Loss: 0.0000, Faulty Rate: 0.2390,
# Epoch 91/100 - Gen Loss: 14.6369, Disc Loss: 0.0000, Faulty Rate: 0.2673,
# Epoch 92/100 - Gen Loss: 14.6538, Disc Loss: 0.0000, Faulty Rate: 0.3300,
# Epoch 93/100 - Gen Loss: 14.6492, Disc Loss: 0.0000, Faulty Rate: 0.2750,
# Epoch 94/100 - Gen Loss: 14.6592, Disc Loss: 0.0000, Faulty Rate: 0.2300,
# Epoch 95/100 - Gen Loss: 14.6595, Disc Loss: 0.0000, Faulty Rate: 0.2490,
# Epoch 96/100 - Gen Loss: 14.6726, Disc Loss: 0.0000, Faulty Rate: 0.2803,
# Epoch 97/100 - Gen Loss: 14.6769, Disc Loss: 0.0000, Faulty Rate: 0.2643,
# Epoch 98/100 - Gen Loss: 14.6835, Disc Loss: 0.0000, Faulty Rate: 0.2247,
# Epoch 99/100 - Gen Loss: 14.6903, Disc Loss: 0.0000, Faulty Rate: 0.2355,
# Epoch 100/100 - Gen Loss: 14.6970, Disc Loss: 0.0000, Faulty Rate: 0.3035,

# %% [markdown]
# ### Testing Minibatch Discriminator

# %%
gan_mindis = SimpleGAN(config, use_minibatch_discrimination=True)

# History tracking
gen_loss_history_mindis = []
disc_loss_history_mindis = []
faulty_rate_history_mindis = []

# Refined: Faulty stats tracking
neg_qty_count_history_mindis = []
neg_qty_sum_history_mindis = []
lower_prev_count_history_mindis = []     # Ask price
higher_next_count_history_mindis = []    # Bid price
diff_positive_sum_history_mindis = []
diff_negative_sum_history_mindis = []

for epoch in range(config.epochs):
    epoch_gen_loss = 0.0
    epoch_disc_loss = 0.0
    num_batches = 0

    for batch in lob_dataset:
        metrics = gan_mindis.train_step(batch)
        epoch_gen_loss += metrics['gen_loss']
        epoch_disc_loss += metrics['disc_loss']
        num_batches += 1

    avg_gen_loss = epoch_gen_loss / num_batches
    avg_disc_loss = epoch_disc_loss / num_batches

    gen_loss_history_mindis.append(float(avg_gen_loss))
    disc_loss_history_mindis.append(float(avg_disc_loss))

    # Generate LOB samples
    noise = tf.random.normal([100, config.z_dim])
    generated_samples = gan_mindis.generator(noise, training=False)

    # Faulty rate
    faulty_rate = compute_faulty_rate(generated_samples)
    faulty_rate_scalar = float(faulty_rate.item())
    faulty_rate_history_mindis.append(faulty_rate_scalar)

    # Faulty stats
    stats = compute_faulty_stats(generated_samples)
    neg_qty_count_history_mindis.append(stats["neg_qty_count"])
    neg_qty_sum_history_mindis.append(stats["neg_qty_sum"])
    lower_prev_count_history_mindis.append(stats["lower_prev_count"])
    higher_next_count_history_mindis.append(stats["higher_next_count"])
    diff_positive_sum_history_mindis.append(stats["diff_positive_sum"])
    diff_negative_sum_history_mindis.append(stats["diff_negative_sum"])

    print(f"[MinDis] Epoch {epoch+1}/{config.epochs} - "
          f"Gen Loss: {avg_gen_loss:.4f}, "
          f"Disc Loss: {avg_disc_loss:.4f}, "
          f"Faulty Rate: {faulty_rate_scalar:.4f}")

# Plotting
plot_training_trends(
    gen_loss_history_mindis, 
    disc_loss_history_mindis, 
    faulty_rate_history_mindis, 
    neg_qty_count_history_mindis,
    neg_qty_sum_history_mindis,
    lower_prev_count_history_mindis,
    higher_next_count_history_mindis,
    diff_positive_sum_history_mindis,
    diff_negative_sum_history_mindis,
    label_prefix="GAN (Minibatch Discrimination)"
)
# Out:
# [MinDis] Epoch 1/100 - Gen Loss: 406.0845, Disc Loss: 0.0001, Faulty Rate: 0.6170
# [MinDis] Epoch 2/100 - Gen Loss: 332.4476, Disc Loss: 0.0000, Faulty Rate: 0.5418
# [MinDis] Epoch 3/100 - Gen Loss: 297.3426, Disc Loss: 0.0000, Faulty Rate: 0.5247
# [MinDis] Epoch 4/100 - Gen Loss: 275.1870, Disc Loss: 0.0000, Faulty Rate: 0.5157
# [MinDis] Epoch 5/100 - Gen Loss: 260.9686, Disc Loss: 0.0000, Faulty Rate: 0.5140
# [MinDis] Epoch 6/100 - Gen Loss: 243.4455, Disc Loss: 0.0000, Faulty Rate: 0.5010
# [MinDis] Epoch 7/100 - Gen Loss: 225.7718, Disc Loss: 0.0000, Faulty Rate: 0.4967
# [MinDis] Epoch 8/100 - Gen Loss: 210.5935, Disc Loss: 0.0000, Faulty Rate: 0.4918
# [MinDis] Epoch 9/100 - Gen Loss: 196.6180, Disc Loss: 0.0000, Faulty Rate: 0.4860
# [MinDis] Epoch 10/100 - Gen Loss: 183.0647, Disc Loss: 0.0000, Faulty Rate: 0.4972
# [MinDis] Epoch 11/100 - Gen Loss: 169.8309, Disc Loss: 0.0000, Faulty Rate: 0.4775
# [MinDis] Epoch 12/100 - Gen Loss: 157.2206, Disc Loss: 0.0000, Faulty Rate: 0.5055
# [MinDis] Epoch 13/100 - Gen Loss: 147.0745, Disc Loss: 0.0000, Faulty Rate: 0.4825
# [MinDis] Epoch 14/100 - Gen Loss: 138.2307, Disc Loss: 0.0000, Faulty Rate: 0.4938
# [MinDis] Epoch 15/100 - Gen Loss: 132.9627, Disc Loss: 0.0000, Faulty Rate: 0.4618
# [MinDis] Epoch 16/100 - Gen Loss: 126.4815, Disc Loss: 0.0000, Faulty Rate: 0.4793
# [MinDis] Epoch 17/100 - Gen Loss: 121.3215, Disc Loss: 0.0000, Faulty Rate: 0.4765
# [MinDis] Epoch 18/100 - Gen Loss: 117.4523, Disc Loss: 0.0000, Faulty Rate: 0.4155
# [MinDis] Epoch 19/100 - Gen Loss: 113.6887, Disc Loss: 0.0000, Faulty Rate: 0.4327
# [MinDis] Epoch 20/100 - Gen Loss: 109.3431, Disc Loss: 0.0000, Faulty Rate: 0.4083
# [MinDis] Epoch 21/100 - Gen Loss: 107.8497, Disc Loss: 0.0000, Faulty Rate: 0.4100
# [MinDis] Epoch 22/100 - Gen Loss: 105.7961, Disc Loss: 0.0000, Faulty Rate: 0.3750
# [MinDis] Epoch 23/100 - Gen Loss: 103.8564, Disc Loss: 0.0000, Faulty Rate: 0.3738
# [MinDis] Epoch 24/100 - Gen Loss: 101.8673, Disc Loss: 0.0000, Faulty Rate: 0.3672
# [MinDis] Epoch 25/100 - Gen Loss: 100.9023, Disc Loss: 0.0000, Faulty Rate: 0.3165
# [MinDis] Epoch 26/100 - Gen Loss: 98.6622, Disc Loss: 0.0000, Faulty Rate: 0.3277
# [MinDis] Epoch 27/100 - Gen Loss: 97.2117, Disc Loss: 0.0000, Faulty Rate: 0.3340
# [MinDis] Epoch 28/100 - Gen Loss: 95.0297, Disc Loss: 0.0000, Faulty Rate: 0.2965
# [MinDis] Epoch 29/100 - Gen Loss: 96.5440, Disc Loss: 0.0000, Faulty Rate: 0.3047
# [MinDis] Epoch 30/100 - Gen Loss: 96.8373, Disc Loss: 0.0000, Faulty Rate: 0.3038
# [MinDis] Epoch 31/100 - Gen Loss: 96.1783, Disc Loss: 0.0000, Faulty Rate: 0.2903
# [MinDis] Epoch 32/100 - Gen Loss: 95.6585, Disc Loss: 0.0000, Faulty Rate: 0.2952
# [MinDis] Epoch 33/100 - Gen Loss: 94.7052, Disc Loss: 0.0000, Faulty Rate: 0.2808
# [MinDis] Epoch 34/100 - Gen Loss: 93.6262, Disc Loss: 0.0000, Faulty Rate: 0.2855
# [MinDis] Epoch 35/100 - Gen Loss: 92.2651, Disc Loss: 0.0000, Faulty Rate: 0.2655
# [MinDis] Epoch 36/100 - Gen Loss: 90.6359, Disc Loss: 0.0000, Faulty Rate: 0.2515
# [MinDis] Epoch 37/100 - Gen Loss: 89.7407, Disc Loss: 0.0000, Faulty Rate: 0.2257
# [MinDis] Epoch 38/100 - Gen Loss: 88.3660, Disc Loss: 0.0000, Faulty Rate: 0.2442
# [MinDis] Epoch 39/100 - Gen Loss: 86.8984, Disc Loss: 0.0000, Faulty Rate: 0.2355
# [MinDis] Epoch 40/100 - Gen Loss: 85.7039, Disc Loss: 0.0000, Faulty Rate: 0.2570
# [MinDis] Epoch 41/100 - Gen Loss: 83.3647, Disc Loss: 0.0000, Faulty Rate: 0.2482
# [MinDis] Epoch 42/100 - Gen Loss: 82.2276, Disc Loss: 0.0000, Faulty Rate: 0.2418
# [MinDis] Epoch 43/100 - Gen Loss: 80.4213, Disc Loss: 0.0000, Faulty Rate: 0.2387
# [MinDis] Epoch 44/100 - Gen Loss: 79.2404, Disc Loss: 0.0000, Faulty Rate: 0.2407
# [MinDis] Epoch 45/100 - Gen Loss: 77.6887, Disc Loss: 0.0000, Faulty Rate: 0.2330
# [MinDis] Epoch 46/100 - Gen Loss: 75.8833, Disc Loss: 0.0000, Faulty Rate: 0.2325
# [MinDis] Epoch 47/100 - Gen Loss: 74.9852, Disc Loss: 0.0000, Faulty Rate: 0.2250
# [MinDis] Epoch 48/100 - Gen Loss: 72.6538, Disc Loss: 0.0000, Faulty Rate: 0.2313
# [MinDis] Epoch 49/100 - Gen Loss: 70.3504, Disc Loss: 0.0000, Faulty Rate: 0.2075
# [MinDis] Epoch 50/100 - Gen Loss: 69.8095, Disc Loss: 0.0000, Faulty Rate: 0.2175
# [MinDis] Epoch 51/100 - Gen Loss: 68.1739, Disc Loss: 0.0000, Faulty Rate: 0.2103
# [MinDis] Epoch 52/100 - Gen Loss: 66.4159, Disc Loss: 0.0000, Faulty Rate: 0.2282
# [MinDis] Epoch 53/100 - Gen Loss: 64.4316, Disc Loss: 0.0000, Faulty Rate: 0.2265
# [MinDis] Epoch 54/100 - Gen Loss: 62.9621, Disc Loss: 0.0000, Faulty Rate: 0.2130
# [MinDis] Epoch 55/100 - Gen Loss: 61.7280, Disc Loss: 0.0000, Faulty Rate: 0.2255
# [MinDis] Epoch 56/100 - Gen Loss: 60.6889, Disc Loss: 0.0000, Faulty Rate: 0.2097
# [MinDis] Epoch 57/100 - Gen Loss: 58.9937, Disc Loss: 0.0000, Faulty Rate: 0.2085
# [MinDis] Epoch 58/100 - Gen Loss: 57.4275, Disc Loss: 0.0000, Faulty Rate: 0.2045
# [MinDis] Epoch 59/100 - Gen Loss: 56.1246, Disc Loss: 0.0000, Faulty Rate: 0.2240
# [MinDis] Epoch 60/100 - Gen Loss: 57.4722, Disc Loss: 0.0000, Faulty Rate: 0.2205
# [MinDis] Epoch 61/100 - Gen Loss: 56.1221, Disc Loss: 0.0000, Faulty Rate: 0.2157
# [MinDis] Epoch 62/100 - Gen Loss: 55.1821, Disc Loss: 0.0000, Faulty Rate: 0.2087
# [MinDis] Epoch 63/100 - Gen Loss: 54.1058, Disc Loss: 0.0000, Faulty Rate: 0.2075
# [MinDis] Epoch 64/100 - Gen Loss: 53.4002, Disc Loss: 0.0000, Faulty Rate: 0.2025
# [MinDis] Epoch 65/100 - Gen Loss: 52.8802, Disc Loss: 0.0000, Faulty Rate: 0.2183
# [MinDis] Epoch 66/100 - Gen Loss: 51.9847, Disc Loss: 0.0000, Faulty Rate: 0.2048
# [MinDis] Epoch 67/100 - Gen Loss: 55.1205, Disc Loss: 0.0000, Faulty Rate: 0.1915
# [MinDis] Epoch 68/100 - Gen Loss: 54.4020, Disc Loss: 0.0000, Faulty Rate: 0.2033
# [MinDis] Epoch 69/100 - Gen Loss: 53.7367, Disc Loss: 0.0000, Faulty Rate: 0.1965
# [MinDis] Epoch 70/100 - Gen Loss: 52.9385, Disc Loss: 0.0000, Faulty Rate: 0.1965
# [MinDis] Epoch 71/100 - Gen Loss: 51.8837, Disc Loss: 0.0000, Faulty Rate: 0.1995
# [MinDis] Epoch 72/100 - Gen Loss: 50.8960, Disc Loss: 0.0000, Faulty Rate: 0.1727
# [MinDis] Epoch 73/100 - Gen Loss: 49.5719, Disc Loss: 0.0000, Faulty Rate: 0.1735
# [MinDis] Epoch 74/100 - Gen Loss: 48.5514, Disc Loss: 0.0000, Faulty Rate: 0.1970
# [MinDis] Epoch 75/100 - Gen Loss: 47.9361, Disc Loss: 0.0000, Faulty Rate: 0.1775
# [MinDis] Epoch 76/100 - Gen Loss: 47.7725, Disc Loss: 0.0000, Faulty Rate: 0.1748
# [MinDis] Epoch 77/100 - Gen Loss: 47.3354, Disc Loss: 0.0000, Faulty Rate: 0.1647
# [MinDis] Epoch 78/100 - Gen Loss: 46.7157, Disc Loss: 0.0000, Faulty Rate: 0.1775
# [MinDis] Epoch 79/100 - Gen Loss: 46.1276, Disc Loss: 0.0000, Faulty Rate: 0.1743
# [MinDis] Epoch 80/100 - Gen Loss: 45.4857, Disc Loss: 0.0000, Faulty Rate: 0.1678
# [MinDis] Epoch 81/100 - Gen Loss: 44.8553, Disc Loss: 0.0000, Faulty Rate: 0.1912
# [MinDis] Epoch 82/100 - Gen Loss: 44.2228, Disc Loss: 0.0000, Faulty Rate: 0.1717
# [MinDis] Epoch 83/100 - Gen Loss: 48.2363, Disc Loss: 0.0000, Faulty Rate: 0.1733
# [MinDis] Epoch 84/100 - Gen Loss: 48.0331, Disc Loss: 0.0000, Faulty Rate: 0.1865
# [MinDis] Epoch 85/100 - Gen Loss: 47.5578, Disc Loss: 0.0000, Faulty Rate: 0.1532
# [MinDis] Epoch 86/100 - Gen Loss: 46.9943, Disc Loss: 0.0000, Faulty Rate: 0.1700
# [MinDis] Epoch 87/100 - Gen Loss: 47.1782, Disc Loss: 0.0000, Faulty Rate: 0.1813
# [MinDis] Epoch 88/100 - Gen Loss: 46.3449, Disc Loss: 0.0000, Faulty Rate: 0.1785
# [MinDis] Epoch 89/100 - Gen Loss: 46.2565, Disc Loss: 0.0000, Faulty Rate: 0.1608
# [MinDis] Epoch 90/100 - Gen Loss: 45.6925, Disc Loss: 0.0000, Faulty Rate: 0.1688
# [MinDis] Epoch 91/100 - Gen Loss: 45.4328, Disc Loss: 0.0000, Faulty Rate: 0.1660
# [MinDis] Epoch 92/100 - Gen Loss: 46.9502, Disc Loss: 0.0000, Faulty Rate: 0.1680
# [MinDis] Epoch 93/100 - Gen Loss: 46.8759, Disc Loss: 0.0000, Faulty Rate: 0.1698
# [MinDis] Epoch 94/100 - Gen Loss: 51.5709, Disc Loss: 0.0000, Faulty Rate: 0.1787
# [MinDis] Epoch 95/100 - Gen Loss: 51.4700, Disc Loss: 0.0000, Faulty Rate: 0.1720
# [MinDis] Epoch 96/100 - Gen Loss: 50.9964, Disc Loss: 0.0000, Faulty Rate: 0.1698
# [MinDis] Epoch 97/100 - Gen Loss: 50.5347, Disc Loss: 0.0000, Faulty Rate: 0.1663
# [MinDis] Epoch 98/100 - Gen Loss: 50.1263, Disc Loss: 0.0000, Faulty Rate: 0.1612
# [MinDis] Epoch 99/100 - Gen Loss: 49.7504, Disc Loss: 0.0000, Faulty Rate: 0.1480
# [MinDis] Epoch 100/100 - Gen Loss: 49.4181, Disc Loss: 0.0000, Faulty Rate: 0.1593
